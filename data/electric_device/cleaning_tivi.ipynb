# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Tivi.csv", header= None, names=['index', 'name', 'price', 'number_of_comment', 'brand', 'size(inch)', 'display', 'type', 'weight', 'comment'])
data
# Out:
#       index                                      name     price  \
# 0         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 1         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 2         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 3         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 4         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# ...     ...                                       ...       ...
# 4821    165     Tivi LED Darling HD 32 inch 32HD962S2   2479000
# 4822    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4823    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4824    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4825    167      Smart Tivi LG 4K 55 inch 55UN7190PTA  10779000
#
#       number_of_comment    brand size(inch)             display  \
# 0                    95  Samsung         55  UHD 4K 3840 x 2160
# 1                    95  Samsung         55  UHD 4K 3840 x 2160
# 2                    95  Samsung         55  UHD 4K 3840 x 2160
# 3                    95  Samsung         55  UHD 4K 3840 x 2160
# 4                    95  Samsung         55  UHD 4K 3840 x 2160
# ...                 ...      ...        ...                 ...
# 4821                 13  DARLING         32   1366 x 768 pixels
# 4822                  3       LG         70  UHD 4K 3840 x 2160
# 4823                  3       LG         70  UHD 4K 3840 x 2160
# 4824                  3       LG         70  UHD 4K 3840 x 2160
# 4825                  0       LG         55  UHD 4K 3840 x 2160
#
#                      type weight  \
# 0              Smart tivi   None
# 1              Smart tivi   None
# 2              Smart tivi   None
# 3              Smart tivi   None
# 4              Smart tivi   None
# ...                   ...    ...
# 4821             Tivi LED     52
# 4822  Smart Tivi  Tivi 4K   None
# 4823  Smart Tivi  Tivi 4K   None
# 4824  Smart Tivi  Tivi 4K   None
# 4825           Smart Tivi    145
#
#                                                 comment
# 0     Giao hàng đúng dự kiến  bọc màng PE cẩn thận k...
# 1     hàng giao đúng hẹn  đúng mẫu mã  chưa kích hoạ...
# 2     Lời khuyên chân thành KHÔNG NÊN MUA TV trên Ti...
# 3     sản phẩm okie nhưng cách thức giao hàng rất k ...
# 4     Giao hàng nhanh hơn dự kiến 02 ngày  đóng gói ...
# ...                                                 ...
# 4821  Sản phẩm tốt trong tầm giá Giao hàng nhanh hơn...
# 4822  giao hàng nhanh  tivi to thật  âm thanh  hình ...
# 4823  Rất dễ cài đặt Quá đẹp Mọi thông tin đều chính...
# 4824                                    Cực kì hài lòng
# 4825                                               None
#
# [4826 rows x 10 columns]

# %%
data.dropna()
# Out:
#       index                                      name     price  \
# 0         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 1         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 2         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 3         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 4         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# ...     ...                                       ...       ...
# 4821    165     Tivi LED Darling HD 32 inch 32HD962S2   2479000
# 4822    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4823    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4824    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4825    167      Smart Tivi LG 4K 55 inch 55UN7190PTA  10779000
#
#       number_of_comment    brand size(inch)             display  \
# 0                    95  Samsung         55  UHD 4K 3840 x 2160
# 1                    95  Samsung         55  UHD 4K 3840 x 2160
# 2                    95  Samsung         55  UHD 4K 3840 x 2160
# 3                    95  Samsung         55  UHD 4K 3840 x 2160
# 4                    95  Samsung         55  UHD 4K 3840 x 2160
# ...                 ...      ...        ...                 ...
# 4821                 13  DARLING         32   1366 x 768 pixels
# 4822                  3       LG         70  UHD 4K 3840 x 2160
# 4823                  3       LG         70  UHD 4K 3840 x 2160
# 4824                  3       LG         70  UHD 4K 3840 x 2160
# 4825                  0       LG         55  UHD 4K 3840 x 2160
#
#                      type weight  \
# 0              Smart tivi   None
# 1              Smart tivi   None
# 2              Smart tivi   None
# 3              Smart tivi   None
# 4              Smart tivi   None
# ...                   ...    ...
# 4821             Tivi LED     52
# 4822  Smart Tivi  Tivi 4K   None
# 4823  Smart Tivi  Tivi 4K   None
# 4824  Smart Tivi  Tivi 4K   None
# 4825           Smart Tivi    145
#
#                                                 comment
# 0     Giao hàng đúng dự kiến  bọc màng PE cẩn thận k...
# 1     hàng giao đúng hẹn  đúng mẫu mã  chưa kích hoạ...
# 2     Lời khuyên chân thành KHÔNG NÊN MUA TV trên Ti...
# 3     sản phẩm okie nhưng cách thức giao hàng rất k ...
# 4     Giao hàng nhanh hơn dự kiến 02 ngày  đóng gói ...
# ...                                                 ...
# 4821  Sản phẩm tốt trong tầm giá Giao hàng nhanh hơn...
# 4822  giao hàng nhanh  tivi to thật  âm thanh  hình ...
# 4823  Rất dễ cài đặt Quá đẹp Mọi thông tin đều chính...
# 4824                                    Cực kì hài lòng
# 4825                                               None
#
# [4805 rows x 10 columns]

# %%
review_predict = data['comment']

# %%
sentiment = pd.read_csv('text.csv',index_col=[0])
sentiment
# Out:
#       text_lb                                               text
# 2         1.0     Ấn tượng, tôi sẽ quay lại vào dịp nghỉ lần sau
# 3         1.0  Quá tuyệt vời , view đẹp , chủ nhà thân thiện ...
# 6         1.0  Phòng nghỉ đáng giá, tiện nghi cơ bản đầy đủ ^...
# 7         1.0  Thuận tiện cho việc đi thăm thú cảnh quan.\nBạ...
# 10        1.0                               Nhân viên thân thiện
# ...       ...                                                ...
# 6994      1.0  Anh chủ rất là nhiệt tình và vui vẻ, phòng sạc...
# 6995      1.0  Vị trí đẹp, mặc dù chúng tôi là khách duy nhất...
# 6996     -1.0  Không có chỗ đỗ xe, phải gửi xe ở ngoài rất tố...
# 6997      1.0  Gửi quản lý cấp cao của khách sạn, Rất tiếc hì...
# 6998      1.0   Phòng đẹp, nhân viên cực kỳ dễ thương và chu đáo
#
# [5199 rows x 2 columns]

# %%
with open('vietnamese_stopwords.txt', encoding="utf8") as f:
    stopwords = []
    for line in f:
        stopwords.append("_".join(line.strip().split()))

# %%
import re
from pyvi import ViTokenizer
def preprocessor(text):
    corpus = []
    for i in range(0, len(text)):
        review = re.sub(r"http\S+", "", str(text[i]))
        review = re.sub(r"#\S+", "", review)
        review = re.sub(r"@\S+", "", review)
        review = re.sub('[_]',' ',review)
        review = re.sub('[^a-zA-Z_áàạảãăắằặẵẳâấầẩậẫđíỉìịĩóòỏọõôốồổộỗơớờởợỡéèẹẽẻêếềểệễúùủũụưứừửựữýỳỷỹỵÁÀẢÃẠĂẮẰẲẲẶẴÂẤẦẬẪẨĐÍÌỈỊĨÓÒỎỌÕÔỐỒỔỘỖƠỚỜỞỢỠÉÈẺẸẼÊẾỀỆỂỄÚÙỦŨỤƯỨỪỬỰỮÝỲỶỴỸ]',
                        ' ',review)
        review = ViTokenizer.tokenize(review)
        review = review.lower()
        review = review.split()
        review = [word for word in review if not word in  set(stopwords)]
        review = ' '.join(review)
        corpus.append(review)
    return corpus

# %%
X = sentiment['text'].values
corpus = preprocessor(X)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect = TfidfVectorizer(analyzer='word', max_features=30000)
tfidf_vect.fit(corpus) 
X_data_tfidf =  tfidf_vect.transform(corpus)

from sklearn.model_selection import train_test_split
X = X_data_tfidf
y = sentiment['text_lb'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0)
clf.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions = clf.predict(X_test)
print('accuracy:',accuracy_score(y_test,predictions))
# Out:
# accuracy: 0.8759615384615385

# %%
from sklearn import svm
classifier = svm.SVC(probability=True)
classifier.fit(X_train, y_train)
train_predictions = classifier.predict(X_train)
predictions = classifier.predict(X_test)
print('accuracy:',accuracy_score(y_test,predictions))
print('confusion matrix:\n',confusion_matrix(y_test,predictions))
print('classification report:\n',classification_report(y_test,predictions))
# Out:
# accuracy: 0.885576923076923
# confusion matrix:
#  [[ 84 100]
#  [ 19 837]]
# classification report:
#                precision    recall  f1-score   support
#
#         -1.0       0.82      0.46      0.59       184
#          1.0       0.89      0.98      0.93       856
#
#     accuracy                           0.89      1040
#    macro avg       0.85      0.72      0.76      1040
# weighted avg       0.88      0.89      0.87      1040

# %%
X_1 = review_predict.values
corpus1 = preprocessor(X_1)
X_data_tfidf_1 =  tfidf_vect.transform(corpus1)

# %%
proba = classifier.predict_proba(X_data_tfidf_1)

# %%
df1 = pd.DataFrame(data=proba, columns=['Negative', 'Positive'])

# %%
data = pd.concat([data, df1], axis = 1).drop(columns = ['comment'])
data
# Out:
#       index                                      name     price  \
# 0         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 1         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 2         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 3         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 4         0  Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# ...     ...                                       ...       ...
# 4821    165     Tivi LED Darling HD 32 inch 32HD962S2   2479000
# 4822    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4823    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4824    166      Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 4825    167      Smart Tivi LG 4K 55 inch 55UN7190PTA  10779000
#
#       number_of_comment    brand size(inch)             display  \
# 0                    95  Samsung         55  UHD 4K 3840 x 2160
# 1                    95  Samsung         55  UHD 4K 3840 x 2160
# 2                    95  Samsung         55  UHD 4K 3840 x 2160
# 3                    95  Samsung         55  UHD 4K 3840 x 2160
# 4                    95  Samsung         55  UHD 4K 3840 x 2160
# ...                 ...      ...        ...                 ...
# 4821                 13  DARLING         32   1366 x 768 pixels
# 4822                  3       LG         70  UHD 4K 3840 x 2160
# 4823                  3       LG         70  UHD 4K 3840 x 2160
# 4824                  3       LG         70  UHD 4K 3840 x 2160
# 4825                  0       LG         55  UHD 4K 3840 x 2160
#
#                      type weight  Negative  Positive
# 0              Smart tivi   None  0.472584  0.527416
# 1              Smart tivi   None  0.699816  0.300184
# 2              Smart tivi   None  0.592164  0.407836
# 3              Smart tivi   None  0.462099  0.537901
# 4              Smart tivi   None  0.353310  0.646690
# ...                   ...    ...       ...       ...
# 4821             Tivi LED     52  0.394358  0.605642
# 4822  Smart Tivi  Tivi 4K   None  0.214509  0.785491
# 4823  Smart Tivi  Tivi 4K   None  0.092053  0.907947
# 4824  Smart Tivi  Tivi 4K   None  0.150261  0.849739
# 4825           Smart Tivi    145  0.040151  0.959849
#
# [4826 rows x 11 columns]

# %%
group_data = data.groupby(['index', 'name', 'price', 'number_of_comment', 'size(inch)', 'brand', 'display', 'type', 'weight'], as_index=False, dropna=False).mean()
group_data['rank_point'] = group_data.number_of_comment * group_data.Positive
group_data
# Out:
#      index                                       name     price  \
# 0        0   Smart Tivi Samsung 4K 55 inch UA55TU8500  12500000
# 1        1   Smart Tivi Samsung 4K 50 inch UA50TU7000   8779000
# 2        2   Smart Tivi Samsung 4K 50 inch UA50RU7100   9553000
# 3        3  Smart Tivi LG Full HD 43 inch 43LM5700PTC   5979000
# 4        4   Smart Tivi Samsung 4K 55 inch UA55TU8100  11279000
# ..     ...                                        ...       ...
# 163    163   Smart Tivi Samsung 4K 43 inch UA43RU7200   7679000
# 164    164       Smart Tivi LG 4K 75 inch 75UM6970PTB  24590000
# 165    165      Tivi LED Darling HD 32 inch 32HD962S2   2479000
# 166    166       Smart Tivi LG 4K 70 inch 70UN7300PTC  20779000
# 167    167       Smart Tivi LG 4K 55 inch 55UN7190PTA  10779000
#
#      number_of_comment size(inch)    brand              display  \
# 0                   95         55  Samsung   UHD 4K 3840 x 2160
# 1                   60         50  Samsung   UHD 4K 3840 x 2160
# 2                  280         50  Samsung   UHD 4K 3840 x 2160
# 3                  176         43       LG  Full HD 1920 x 1080
# 4                   62         55  Samsung   UHD 4K 3840 x 2160
# ..                 ...        ...      ...                  ...
# 163                 20         43  Samsung   3840 x 2160 pixels
# 164                  1       None       LG                 None
# 165                 13         32  DARLING    1366 x 768 pixels
# 166                  3         70       LG   UHD 4K 3840 x 2160
# 167                  0         55       LG   UHD 4K 3840 x 2160
#
#                     type weight  Negative  Positive  rank_point
# 0             Smart tivi   None  0.237691  0.762309   72.419334
# 1             Smart Tivi    116  0.238998  0.761002   45.660110
# 2             Smart Tivi    139  0.213362  0.786638  220.258729
# 3             Smart tivi   None  0.210971  0.789029  138.869179
# 4             Smart tivi   None  0.191731  0.808269   50.112692
# ..                   ...    ...       ...       ...         ...
# 163             Smart TV     98  0.262327  0.737673   14.753456
# 164                 None   None  0.040151  0.959849    0.959849
# 165             Tivi LED     52  0.307010  0.692990    9.008872
# 166  Smart Tivi  Tivi 4K   None  0.152274  0.847726    2.543177
# 167           Smart Tivi    145  0.040151  0.959849    0.000000
#
# [168 rows x 12 columns]

# %%
rank_data = group_data.drop(columns=['index', 'name', 'brand', 'display', 'type', 'number_of_comment', 'Negative', 'Positive'])
rank_data.values
# Out:
# array([[12500000, '55', 'None', 72.41933407424246],
#        [8779000, '50', '116', 45.66010968231055],
#        [9553000, '50', '139', 220.25872875849572],
#        [5979000, '43', 'None', 138.86917935492886],
#        [11279000, '55', 'None', 50.1126923718781],
#        [17599000, '70', 'None', 64.02133176897067],
#        [13990000, '55', 'None', 17.763970741712495],
#        [7190000, '43', '9', 81.73531879372953],
#        [11790000, '55', '174', 67.40828004892009],
#        [4279000, '40', '83', 109.8367041742274],
#        [2979000, '32', '45', 53.750158934494095],
#        [2479000, '32', '53', 91.85590246286841],
#        [10390000, '55', 'None', 26.999696358754267],
#        [10979000, '49', '155', 54.243291666501264],
#        [16979000, '65', '216', 34.94313957213298],
#        [3990000, '32', '49', 51.34156385874606],
#        [13890000, '55', '187', 41.60969447502125],
#        [9950000, '55', '139', 8.370811699336324],
#        [15490000, '55', '159', 25.175500777403805],
#        [5450000, '32', '39', 43.262916302933036],
#        [16450000, '65', '209', 14.061666295506146],
#        [4679000, 'None', 'None', 25.348989700509794],
#        [4379000, '32', '39', 80.05397805298642],
#        [7779000, '43', '83', 12.62360192943556],
#        [13879000, '50', '122', 16.0041982752088],
#        [6950000, '43', '82', 21.07199379080174],
#        [8879000, '50', '114', 21.990693264541093],
#        [7279000, 'None', 'None', 34.61808847858384],
#        [16379000, '55', 'None', 18.10750944587918],
#        [7779000, '43', 'None', 18.109658925828313],
#        [1949000, '24', '24', 35.170889528236465],
#        [9590000, '55', '175', 106.8082549931024],
#        [11229000, '50', '143', 10.242884184328728],
#        [26879000, '55', 'None', 19.035797041908634],
#        [9979000, '49', '125', 10.52033125667862],
#        [10979000, '55', 'None', 5.721426227673543],
#        [11479000, 'None', '92', 10.495270539203705],
#        [9190000, '49', '111', 22.278230740039184],
#        [22479000, 'None', 'None', 6.513883939085833],
#        [10479000, '50', '116', 12.193451900660781],
#        [6979000, '43', 'None', 87.48749228834122],
#        [6990000, '43', '82', 2.4370912745724973],
#        [10190000, '43', '101', 3.398957509010108],
#        [8890000, '43', '83', 13.116960076507231],
#        [16779000, 'None', 'None', 12.828972385572646],
#        [20739000, '65', '201', 6.048665934283202],
#        [12990000, '49', '125', 9.457242889441623],
#        [8879000, '50', '139', 15.07675118992387],
#        [1959000, '25', nan, 14.463275324952367],
#        [9600000, '43', '102', 44.633946236057255],
#        [14919000, '55', '189', 15.252949848602295],
#        [11929000, '49', 'None', 3.1974682649915396],
#        [9439000, '43', 'None', 6.068812325298614],
#        [5179000, '43', 'None', 13.315777868070432],
#        [19209000, '70', '314', 17.78584348413712],
#        [21480000, '65', 'None', 17.26368953801627],
#        [8690000, '55', 'None', 24.309699717400754],
#        [20079000, '65', '249', 4.019519217325587],
#        [3679000, 'None', 'None', 1.6955960046572467],
#        [20790000, 'None', 'None', 4.84609428415448],
#        [10661000, '55', '143', 154.27338772505752],
#        [29579000, 'None', 'None', 4.2794663365512084],
#        [8749000, '43', '10', 5.425793559416675],
#        [3379000, '32', '5', 33.36812956288648],
#        [17979000, '65', '209', 3.395074998220459],
#        [16399000, '65', '28', 16.2107542713942],
#        [17479000, '49', '175', 1.8095884941688785],
#        [4950000, '43', '7', 10.263843724800667],
#        [6879000, '40', '81', 67.15325939166686],
#        [3779000, 'None', 'None', 14.404510938167473],
#        [18169000, '55', '191', 4.263259341209844],
#        [4969000, '40', 'None', 5.51965271064495],
#        [18779000, '55', 'None', 6.0292150442544425],
#        [10239000, '50', '116', 0.0],
#        [2779000, '32', 'None', 4.750950508696939],
#        [5832000, 'None', '81', 4.974269789347913],
#        [9490000, 'None', 'None', 4.836392810024946],
#        [12679000, '65', '12', 3.231666834139438],
#        [24479000, '65', 'None', 1.3772368248168843],
#        [24990000, '55', '18', 0.0],
#        [11990000, '55', '124', 80.89195936309794],
#        [32990000, 'None', '23', 1.3095256690873618],
#        [26699000, 'None', 'None', 0.0],
#        [12690000, '55', '171', 40.483846545171396],
#        [3679000, '32', '39', 21.174974013472823],
#        [10260000, '49', 'None', 2.537727322994835],
#        [4979000, 'None', 'None', 9.78500548035856],
#        [31190000, '65', '278', 1.699478754505054],
#        [6179000, '32', 'None', 8.334447238229636],
#        [7290000, '43', '98', 61.88207769146194],
#        [8149000, '49', '176', 22.032730968974224],
#        [13190000, 'None', 'None', 7.351466191092618],
#        [11679000, '55', 'None', 2.311047054400285],
#        [10890000, '50', 'None', 17.065718649569792],
#        [12390000, '55', 'Smart Tivi', 1.9196982338327029],
#        [8599000, '49', '146', 17.724044768963402],
#        [14879000, '49', '12', 0.0],
#        [15790000, '49', 'None', 2.014787955208994],
#        [8959000, '55', '12', 23.512694512749693],
#        [11990000, '65', '18', 17.596866303920706],
#        [2779000, 'None', 'None', 6.0198907647864495],
#        [4490000, '32', 'None', 1.1859041577931384],
#        [8159000, '50', '165', 24.88027703328333],
#        [9190000, '49', '143', 31.678555400025278],
#        [19290000, '70', '247', 0.0],
#        [3970000, '40', '71', 15.589001256311516],
#        [19670000, 'None', 'None', 0.0],
#        [4869000, '32', '48', 19.874792495483963],
#        [13990000, '43', '113', 1.699478754505054],
#        [17990000, '65', '211', 4.6999134193854175],
#        [3709000, 'None', 'None', 5.813212633779891],
#        [7149000, '50', 'None', 4.691050239885287],
#        [8659000, 'None', '83', 1.3847107347135974],
#        [7266000, '43', 'None', 6.203079868288718],
#        [5459000, '32', '52', 29.92618467743051],
#        [2890000, '32', 'None', 39.05912013951455],
#        [31579000, '55', 'None', 1.6645882214960879],
#        [17390000, 'None', 'None', 0.849739377252527],
#        [5479000, '32', '41', 2.463424649599932],
#        [7049000, '50', 'None', 11.591457178305571],
#        [5470000, '43', '75', 6.531024592507242],
#        [21490000, '65', '28', 2.1084818696985907],
#        [10490000, '49', '123', 4.230284966869769],
#        [25859000, '55', 'None', 2.594989712012553],
#        [4050000, '40', 'None', 8.57157366983083],
#        [4190000, 'None', 'None', 0.0],
#        [22879000, '55', '21', 5.067561162855913],
#        [11990000, '49', '124', 23.289972588764115],
#        [5049000, '32', '41', 1.699478754505054],
#        [38290000, '65', '254', 2.5529326735060405],
#        [11500000, 'None', '14', 0.662760890464875],
#        [26150000, '65', '281', 0.7732657647692882],
#        [5179000, '43', 'None', 0.0],
#        [2190000, 'None', 'None', 0.0],
#        [8879000, '43', 'None', 1.699478754505054],
#        [15409000, 'None', '177', 2.7421371348740764],
#        [26359000, '75', '308', 0.9939104701955742],
#        [8690000, '50', '138', 39.80883829132139],
#        [5790000, '43', '75', 3.3507898584584708],
#        [2490000, '32', 'None', 1.4670690505565],
#        [14879000, 'None', 'None', 6.651657743982646],
#        [11239000, '55', 'None', 16.95739063031246],
#        [14290000, '49', 'None', 2.6906065940300143],
#        [23690000, 'None', '22', 0.0],
#        [20579000, 'None', 'None', 0.849739377252527],
#        [24049000, '65', '226', 0.849739377252527],
#        [4190000, '32', 'None', 3.463115325384629],
#        [3319000, '32', '43', 6.060086615343492],
#        [9939000, '50', '114', 18.25685095280043],
#        [6329000, '43', 'None', 1.7101767774376904],
#        [36979000, '75', '391', 0.0],
#        [7999000, '49', '139', 1.6176717509180902],
#        [8190000, '43', '102', 0.7092302100559151],
#        [5990000, '43', '81', 18.9076985157999],
#        [7390000, 'None', 'None', 2.549218131757581],
#        [1200000, 'None', 'None', 6.110396365303298],
#        [11999000, '55', '197', 9.309234580139279],
#        [11179000, '50', '132', 2.2977060282856288],
#        [13629000, '49', 'None', 12.31648249348287],
#        [4190000, '32', '39', 6.362763896243338],
#        [11339000, '55', '202', 25.9868510388913],
#        [13950000, '49', 'None', 4.0576829042701315],
#        [4590000, 'None', 'None', 29.414961515063503],
#        [7679000, '43', '98', 14.753455706503651],
#        [24590000, 'None', 'None', 0.9598491169163514],
#        [2479000, '32', '52', 9.008871637136457],
#        [20779000, '70', 'None', 2.5431772063511433],
#        [10779000, '55', '145', 0.0]], dtype=object)

# %%
pd.set_option('display.max_rows', rank_data.shape[0]+1)
rank_data[lambda col :rank_data.columns] = rank_data[lambda col :rank_data.columns].replace(r'\D+', np.NaN, regex=True)
rank_data
# Out:
#         price size(inch) weight  rank_point
# 0    12500000         55    NaN   72.419334
# 1     8779000         50    116   45.660110
# 2     9553000         50    139  220.258729
# 3     5979000         43    NaN  138.869179
# 4    11279000         55    NaN   50.112692
# 5    17599000         70    NaN   64.021332
# 6    13990000         55    NaN   17.763971
# 7     7190000         43      9   81.735319
# 8    11790000         55    174   67.408280
# 9     4279000         40     83  109.836704
# 10    2979000         32     45   53.750159
# 11    2479000         32     53   91.855902
# 12   10390000         55    NaN   26.999696
# 13   10979000         49    155   54.243292
# 14   16979000         65    216   34.943140
# 15    3990000         32     49   51.341564
# 16   13890000         55    187   41.609694
# 17    9950000         55    139    8.370812
# 18   15490000         55    159   25.175501
# 19    5450000         32     39   43.262916
# 20   16450000         65    209   14.061666
# 21    4679000        NaN    NaN   25.348990
# 22    4379000         32     39   80.053978
# 23    7779000         43     83   12.623602
# 24   13879000         50    122   16.004198
# 25    6950000         43     82   21.071994
# 26    8879000         50    114   21.990693
# 27    7279000        NaN    NaN   34.618088
# 28   16379000         55    NaN   18.107509
# 29    7779000         43    NaN   18.109659
# 30    1949000         24     24   35.170890
# 31    9590000         55    175  106.808255
# 32   11229000         50    143   10.242884
# 33   26879000         55    NaN   19.035797
# 34    9979000         49    125   10.520331
# 35   10979000         55    NaN    5.721426
# 36   11479000        NaN     92   10.495271
# 37    9190000         49    111   22.278231
# 38   22479000        NaN    NaN    6.513884
# 39   10479000         50    116   12.193452
# 40    6979000         43    NaN   87.487492
# 41    6990000         43     82    2.437091
# 42   10190000         43    101    3.398958
# 43    8890000         43     83   13.116960
# 44   16779000        NaN    NaN   12.828972
# 45   20739000         65    201    6.048666
# 46   12990000         49    125    9.457243
# 47    8879000         50    139   15.076751
# 48    1959000         25    NaN   14.463275
# 49    9600000         43    102   44.633946
# 50   14919000         55    189   15.252950
# 51   11929000         49    NaN    3.197468
# 52    9439000         43    NaN    6.068812
# 53    5179000         43    NaN   13.315778
# 54   19209000         70    314   17.785843
# 55   21480000         65    NaN   17.263690
# 56    8690000         55    NaN   24.309700
# 57   20079000         65    249    4.019519
# 58    3679000        NaN    NaN    1.695596
# 59   20790000        NaN    NaN    4.846094
# 60   10661000         55    143  154.273388
# 61   29579000        NaN    NaN    4.279466
# 62    8749000         43     10    5.425794
# 63    3379000         32      5   33.368130
# 64   17979000         65    209    3.395075
# 65   16399000         65     28   16.210754
# 66   17479000         49    175    1.809588
# 67    4950000         43      7   10.263844
# 68    6879000         40     81   67.153259
# 69    3779000        NaN    NaN   14.404511
# 70   18169000         55    191    4.263259
# 71    4969000         40    NaN    5.519653
# 72   18779000         55    NaN    6.029215
# 73   10239000         50    116    0.000000
# 74    2779000         32    NaN    4.750951
# 75    5832000        NaN     81    4.974270
# 76    9490000        NaN    NaN    4.836393
# 77   12679000         65     12    3.231667
# 78   24479000         65    NaN    1.377237
# 79   24990000         55     18    0.000000
# 80   11990000         55    124   80.891959
# 81   32990000        NaN     23    1.309526
# 82   26699000        NaN    NaN    0.000000
# 83   12690000         55    171   40.483847
# 84    3679000         32     39   21.174974
# 85   10260000         49    NaN    2.537727
# 86    4979000        NaN    NaN    9.785005
# 87   31190000         65    278    1.699479
# 88    6179000         32    NaN    8.334447
# 89    7290000         43     98   61.882078
# 90    8149000         49    176   22.032731
# 91   13190000        NaN    NaN    7.351466
# 92   11679000         55    NaN    2.311047
# 93   10890000         50    NaN   17.065719
# 94   12390000         55    NaN    1.919698
# 95    8599000         49    146   17.724045
# 96   14879000         49     12    0.000000
# 97   15790000         49    NaN    2.014788
# 98    8959000         55     12   23.512695
# 99   11990000         65     18   17.596866
# 100   2779000        NaN    NaN    6.019891
# 101   4490000         32    NaN    1.185904
# 102   8159000         50    165   24.880277
# 103   9190000         49    143   31.678555
# 104  19290000         70    247    0.000000
# 105   3970000         40     71   15.589001
# 106  19670000        NaN    NaN    0.000000
# 107   4869000         32     48   19.874792
# 108  13990000         43    113    1.699479
# 109  17990000         65    211    4.699913
# 110   3709000        NaN    NaN    5.813213
# 111   7149000         50    NaN    4.691050
# 112   8659000        NaN     83    1.384711
# 113   7266000         43    NaN    6.203080
# 114   5459000         32     52   29.926185
# 115   2890000         32    NaN   39.059120
# 116  31579000         55    NaN    1.664588
# 117  17390000        NaN    NaN    0.849739
# 118   5479000         32     41    2.463425
# 119   7049000         50    NaN   11.591457
# 120   5470000         43     75    6.531025
# 121  21490000         65     28    2.108482
# 122  10490000         49    123    4.230285
# 123  25859000         55    NaN    2.594990
# 124   4050000         40    NaN    8.571574
# 125   4190000        NaN    NaN    0.000000
# 126  22879000         55     21    5.067561
# 127  11990000         49    124   23.289973
# 128   5049000         32     41    1.699479
# 129  38290000         65    254    2.552933
# 130  11500000        NaN     14    0.662761
# 131  26150000         65    281    0.773266
# 132   5179000         43    NaN    0.000000
# 133   2190000        NaN    NaN    0.000000
# 134   8879000         43    NaN    1.699479
# 135  15409000        NaN    177    2.742137
# 136  26359000         75    308    0.993910
# 137   8690000         50    138   39.808838
# 138   5790000         43     75    3.350790
# 139   2490000         32    NaN    1.467069
# 140  14879000        NaN    NaN    6.651658
# 141  11239000         55    NaN   16.957391
# 142  14290000         49    NaN    2.690607
# 143  23690000        NaN     22    0.000000
# 144  20579000        NaN    NaN    0.849739
# 145  24049000         65    226    0.849739
# 146   4190000         32    NaN    3.463115
# 147   3319000         32     43    6.060087
# 148   9939000         50    114   18.256851
# 149   6329000         43    NaN    1.710177
# 150  36979000         75    391    0.000000
# 151   7999000         49    139    1.617672
# 152   8190000         43    102    0.709230
# 153   5990000         43     81   18.907699
# 154   7390000        NaN    NaN    2.549218
# 155   1200000        NaN    NaN    6.110396
# 156  11999000         55    197    9.309235
# 157  11179000         50    132    2.297706
# 158  13629000         49    NaN   12.316482
# 159   4190000         32     39    6.362764
# 160  11339000         55    202   25.986851
# 161  13950000         49    NaN    4.057683
# 162   4590000        NaN    NaN   29.414962
# 163   7679000         43     98   14.753456
# 164  24590000        NaN    NaN    0.959849
# 165   2479000         32     52    9.008872
# 166  20779000         70    NaN    2.543177
# 167  10779000         55    145    0.000000

# %%
from sklearn.impute import KNNImputer
data_imputed = rank_data.values
ix = [i for i in range(data_imputed.shape[1]) if i != len(rank_data.columns)]
X = data_imputed[:, ix]
imputer = KNNImputer(n_neighbors=len(rank_data.columns))
imputer.fit(X)
Xtrans = imputer.transform(X)
X.shape
# Out:
# (168, 4)

# %%
rank_data = pd.DataFrame(Xtrans,index=rank_data.index, columns=rank_data.columns)
rank_data.describe()
# Out:
#               price  size(inch)      weight  rank_point
# count  1.680000e+02  168.000000  168.000000  168.000000
# mean   1.173284e+07   49.044643  112.849702   19.787631
# std    7.501149e+06   11.351037   72.552707   30.462729
# min    1.200000e+06   24.000000    5.000000    0.000000
# 25%    5.987250e+06   43.000000   51.250000    2.541815
# 50%    1.008450e+07   49.125000  108.500000    8.471193
# 75%    1.542925e+07   55.000000  153.500000   22.094106
# max    3.829000e+07   75.000000  391.000000  220.258729

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def print_heatmap(cor_method):
  corrmat = rank_data.corr(method=cor_method)
  print("{} correlation heatmap\n".format(cor_method))
  f, ax = plt.subplots(figsize=(12, 9))
  sns.heatmap(corrmat,annot= True, vmax=.8, square=True)
  plt.show()
print_heatmap('pearson')
print_heatmap('spearman')
# Out:
# pearson correlation heatmap
# spearman correlation heatmap

# %%
from sklearn.preprocessing import StandardScaler

Standard_scaler = StandardScaler()
Xtrans = Standard_scaler.fit_transform(Xtrans)

# %%
rank_data_scaled = pd.DataFrame(Xtrans,index=rank_data.index, columns=rank_data.columns)

# %%
from skcriteria import Data, MIN, MAX
ranking = Data(
    rank_data_scaled,
    [MIN, MAX, MIN, MAX],
    cnames = rank_data.columns,
    weights = [10,1,1,10]
)

# %%
from skcriteria.madm import simple
dm = simple.WeightedSum(mnorm = "sum",wnorm = "sum")
dec = dm.decide(ranking)

# %%
rank_data['rank'] = dec.rank_
rank_data.sort_values(by=['rank'])
# Out:
#           price  size(inch)  weight  rank_point  rank
# 2     9553000.0       50.00  139.00  220.258729     1
# 60   10661000.0       55.00  143.00  154.273388     2
# 3     5979000.0       43.00   69.50  138.869179     3
# 9     4279000.0       40.00   83.00  109.836704     4
# 31    9590000.0       55.00  175.00  106.808255     5
# 11    2479000.0       32.00   53.00   91.855902     6
# 40    6979000.0       43.00   63.50   87.487492     7
# 80   11990000.0       55.00  124.00   80.891959     8
# 7     7190000.0       43.00    9.00   81.735319     9
# 22    4379000.0       32.00   39.00   80.053978    10
# 0    12500000.0       55.00  126.25   72.419334    11
# 8    11790000.0       55.00  174.00   67.408280    12
# 5    17599000.0       70.00  196.50   64.021332    13
# 68    6879000.0       40.00   81.00   67.153259    14
# 89    7290000.0       43.00   98.00   61.882078    15
# 13   10979000.0       49.00  155.00   54.243292    16
# 4    11279000.0       55.00  142.25   50.112692    17
# 10    2979000.0       32.00   45.00   53.750159    18
# 15    3990000.0       32.00   49.00   51.341564    19
# 1     8779000.0       50.00  116.00   45.660110    20
# 49    9600000.0       43.00  102.00   44.633946    21
# 16   13890000.0       55.00  187.00   41.609694    22
# 83   12690000.0       55.00  171.00   40.483847    23
# 19    5450000.0       32.00   39.00   43.262916    24
# 137   8690000.0       50.00  138.00   39.808838    25
# 14   16979000.0       65.00  216.00   34.943140    26
# 115   2890000.0       32.00   48.25   39.059120    27
# 27    7279000.0       44.75   67.75   34.618088    28
# 103   9190000.0       49.00  143.00   31.678555    29
# 30    1949000.0       24.00   24.00   35.170890    30
# 63    3379000.0       32.00    5.00   33.368130    31
# 12   10390000.0       55.00  114.00   26.999696    32
# 114   5459000.0       32.00   52.00   29.926185    33
# 160  11339000.0       55.00  202.00   25.986851    34
# 162   4590000.0       34.00   44.25   29.414962    35
# 18   15490000.0       55.00  159.00   25.175501    36
# 56    8690000.0       55.00   86.75   24.309700    37
# 102   8159000.0       50.00  165.00   24.880277    38
# 98    8959000.0       55.00   12.00   23.512695    39
# 21    4679000.0       36.75   33.75   25.348990    40
# 127  11990000.0       49.00  124.00   23.289973    41
# 37    9190000.0       49.00  111.00   22.278231    42
# 26    8879000.0       50.00  114.00   21.990693    43
# 90    8149000.0       49.00  176.00   22.032731    44
# 54   19209000.0       70.00  314.00   17.785843    45
# 99   11990000.0       65.00   18.00   17.596866    46
# 25    6950000.0       43.00   82.00   21.071994    47
# 33   26879000.0       55.00  208.25   19.035797    48
# 55   21480000.0       65.00  124.75   17.263690    49
# 28   16379000.0       55.00  153.00   18.107509    50
# 65   16399000.0       65.00   28.00   16.210754    51
# 6    13990000.0       55.00  108.50   17.763971    52
# 148   9939000.0       50.00  114.00   18.256851    53
# 84    3679000.0       32.00   39.00   21.174974    54
# 141  11239000.0       55.00  158.00   16.957391    55
# 153   5990000.0       43.00   81.00   18.907699    56
# 95    8599000.0       49.00  146.00   17.724045    57
# 93   10890000.0       50.00  143.75   17.065719    58
# 29    7779000.0       43.00  124.00   18.109659    59
# 107   4869000.0       32.00   48.00   19.874792    60
# 20   16450000.0       65.00  209.00   14.061666    61
# 50   14919000.0       55.00  189.00   15.252950    62
# 24   13879000.0       50.00  122.00   16.004198    63
# 47    8879000.0       50.00  139.00   15.076751    64
# 44   16779000.0       62.50  157.00   12.828972    65
# 105   3970000.0       40.00   71.00   15.589001    66
# 163   7679000.0       43.00   98.00   14.753456    67
# 39   10479000.0       50.00  116.00   12.193452    68
# 53    5179000.0       43.00   34.75   13.315778    69
# 158  13629000.0       49.00  136.75   12.316482    70
# 69    3779000.0       36.00   41.00   14.404511    71
# 43    8890000.0       43.00   83.00   13.116960    72
# 119   7049000.0       50.00   63.50   11.591457    73
# 23    7779000.0       43.00   83.00   12.623602    74
# 36   11479000.0       53.75   92.00   10.495271    75
# 48    1959000.0       25.00   43.50   14.463275    76
# 34    9979000.0       49.00  125.00   10.520331    77
# 32   11229000.0       50.00  143.00   10.242884    78
# 156  11999000.0       55.00  197.00    9.309235    79
# 46   12990000.0       49.00  125.00    9.457243    80
# 17    9950000.0       55.00  139.00    8.370812    81
# 67    4950000.0       43.00    7.00   10.263844    82
# 38   22479000.0       62.50   74.25    6.513884    83
# 45   20739000.0       65.00  201.00    6.048666    84
# 91   13190000.0       54.50  107.50    7.351466    85
# 86    4979000.0       36.75   33.75    9.785005    86
# 59   20790000.0       66.25  181.25    4.846094    87
# 109  17990000.0       65.00  211.00    4.699913    88
# 140  14879000.0       52.00  134.25    6.651658    89
# 124   4050000.0       40.00   60.50    8.571574    90
# 72   18779000.0       55.00  240.75    6.029215    91
# 35   10979000.0       55.00  143.75    5.721426    92
# 57   20079000.0       65.00  249.00    4.019519    93
# 61   29579000.0       62.50  222.50    4.279466    94
# 165   2479000.0       32.00   52.00    9.008872    95
# 126  22879000.0       55.00   21.00    5.067561    96
# 64   17979000.0       65.00  209.00    3.395075    97
# 166  20779000.0       70.00  181.25    2.543177    98
# 77   12679000.0       65.00   12.00    3.231667    99
# 120   5470000.0       43.00   75.00    6.531025   100
# 88    6179000.0       32.00   69.50    8.334447   101
# 136  26359000.0       75.00  308.00    0.993910   102
# 70   18169000.0       55.00  191.00    4.263259   103
# 113   7266000.0       43.00   67.75    6.203080   104
# 129  38290000.0       65.00  254.00    2.552933   105
# 52    9439000.0       43.00  131.75    6.068812   106
# 111   7149000.0       50.00   67.75    4.691050   107
# 121  21490000.0       65.00   28.00    2.108482   108
# 76    9490000.0       47.75  131.75    4.836393   109
# 62    8749000.0       43.00   10.00    5.425794   110
# 87   31190000.0       65.00  278.00    1.699479   111
# 150  36979000.0       75.00  391.00    0.000000   112
# 122  10490000.0       49.00  123.00    4.230285   113
# 161  13950000.0       49.00  108.50    4.057683   114
# 71    4969000.0       40.00   33.75    5.519653   115
# 78   24479000.0       65.00   71.75    1.377237   116
# 81   32990000.0       65.00   23.00    1.309526   117
# 144  20579000.0       66.25  181.25    0.849739   118
# 123  25859000.0       55.00  208.25    2.594990   119
# 159   4190000.0       32.00   39.00    6.362764   120
# 75    5832000.0       40.25   81.00    4.974270   121
# 145  24049000.0       65.00  226.00    0.849739   122
# 104  19290000.0       70.00  247.00    0.000000   123
# 131  26150000.0       65.00  281.00    0.773266   124
# 110   3709000.0       34.00   41.00    5.813213   125
# 92   11679000.0       55.00   74.50    2.311047   126
# 147   3319000.0       32.00   43.00    6.060087   127
# 135  15409000.0       52.00  177.00    2.742137   128
# 100   2779000.0       32.00   48.25    6.019891   129
# 51   11929000.0       49.00  115.75    3.197468   130
# 117  17390000.0       62.25  202.75    0.849739   131
# 94   12390000.0       55.00   99.50    1.919698   132
# 164  24590000.0       60.00  136.75    0.959849   133
# 155   1200000.0       28.25   43.50    6.110396   134
# 142  14290000.0       49.00  108.50    2.690607   135
# 116  31579000.0       55.00  250.00    1.664588   136
# 106  19670000.0       65.00  252.75    0.000000   137
# 85   10260000.0       49.00  114.00    2.537727   138
# 157  11179000.0       50.00  132.00    2.297706   139
# 42   10190000.0       43.00  101.00    3.398958   140
# 138   5790000.0       43.00   75.00    3.350790   141
# 82   26699000.0       62.50  208.25    0.000000   142
# 97   15790000.0       49.00  143.25    2.014788   143
# 74    2779000.0       32.00   48.25    4.750951   144
# 154   7390000.0       44.75   72.00    2.549218   145
# 66   17479000.0       49.00  175.00    1.809588   146
# 143  23690000.0       60.00   22.00    0.000000   147
# 151   7999000.0       49.00  139.00    1.617672   148
# 41    6990000.0       43.00   82.00    2.437091   149
# 130  11500000.0       53.75   14.00    0.662761   150
# 112   8659000.0       49.25   83.00    1.384711   151
# 79   24990000.0       55.00   18.00    0.000000   152
# 167  10779000.0       55.00  145.00    0.000000   153
# 149   6329000.0       43.00   79.50    1.710177   154
# 108  13990000.0       43.00  113.00    1.699479   155
# 134   8879000.0       43.00   87.00    1.699479   156
# 146   4190000.0       32.00   52.50    3.463115   157
# 73   10239000.0       50.00  116.00    0.000000   158
# 96   14879000.0       49.00   12.00    0.000000   159
# 152   8190000.0       43.00  102.00    0.709230   160
# 118   5479000.0       32.00   41.00    2.463425   161
# 58    3679000.0       34.00   41.00    1.695596   162
# 132   5179000.0       43.00   34.75    0.000000   163
# 128   5049000.0       32.00   41.00    1.699479   164
# 139   2490000.0       32.00   43.50    1.467069   165
# 101   4490000.0       32.00   52.25    1.185904   166
# 125   4190000.0       36.00   52.50    0.000000   167
# 133   2190000.0       28.25   43.50    0.000000   168

# %%
cols_to_keep = ['index', 'name', 'brand', 'number_of_comment', 'Negative', 'Positive']
group_data = group_data.drop(group_data.columns.difference(cols_to_keep), axis=1)

# %%
pd.concat([group_data, rank_data], axis=1, join="inner").to_csv('tivi_done.csv')
