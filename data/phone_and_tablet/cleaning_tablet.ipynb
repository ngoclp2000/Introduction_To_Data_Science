# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("tablet.csv")
data
# Out:
#       index                                               name    price  \
# 0         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 1         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 2         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 3         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 4         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# ...     ...                                                ...      ...
# 1978     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1979     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1980     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1981     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1982     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
#
#       number_of_comment  pin(ah)   brand  front_cam(MP)  rear_cam(MP)  weight  \
# 0                   183      NaN   Apple            8.0           NaN   495.0
# 1                   183      NaN   Apple            8.0           NaN   495.0
# 2                   183      NaN   Apple            8.0           NaN   495.0
# 3                   183      NaN   Apple            8.0           NaN   495.0
# 4                   183      NaN   Apple            8.0           NaN   495.0
# ...                 ...      ...     ...            ...           ...     ...
# 1978                165     4.75  Kindle            2.0           2.0   363.0
# 1979                165     4.75  Kindle            2.0           2.0   363.0
# 1980                165     4.75  Kindle            2.0           2.0   363.0
# 1981                165     4.75  Kindle            2.0           2.0   363.0
# 1982                165     4.75  Kindle            2.0           2.0   363.0
#
#       RAM(GB)                      screen_size  \
# 0         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 1         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 2         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 3         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 4         NaN  250mm x 174mm X 7.5mm 10.2 inch
# ...       ...                              ...
# 1978      1.0        214 x 128 x 9.7 mm 8 inch
# 1979      1.0        214 x 128 x 9.7 mm 8 inch
# 1980      1.0        214 x 128 x 9.7 mm 8 inch
# 1981      1.0        214 x 128 x 9.7 mm 8 inch
# 1982      1.0        214 x 128 x 9.7 mm 8 inch
#
#                                                 comment
# 0     Mình đặt lúc 17h30 chiều và 20h tối nhận máy m...
# 1     Mua cho người già sử dụng nên con này là đủ vớ...
# 2     Hàng chính hãng nguyên seal chưa active giao n...
# 3     Hàng chính hãng nguyên seal chưa kích hoạt mã ...
# 4     Mình cho 3 sao là bởi vì 1 Sản phẩm giá trị ca...
# ...                                                 ...
# 1978             Đáng đồng tiền bỏ ra Không mong gì hơn
# 1979  Không nên mua bởi vì tôi mua máy chạy rất chậm...
# 1980  Máy dùng tạm được màn hình chất lượng thấp mờ ...
# 1981  Đây là lựa chọn tốt trong tầm giá tiền dưới 2 ...
# 1982                                                NaN
#
# [1983 rows x 12 columns]

# %%
review_predict = data['comment']

# %%
sentiment = pd.read_csv('text.csv',index_col=[0])
sentiment
# Out:
#       text_lb                                               text
# 2         1.0     Ấn tượng, tôi sẽ quay lại vào dịp nghỉ lần sau
# 3         1.0  Quá tuyệt vời , view đẹp , chủ nhà thân thiện ...
# 6         1.0  Phòng nghỉ đáng giá, tiện nghi cơ bản đầy đủ ^...
# 7         1.0  Thuận tiện cho việc đi thăm thú cảnh quan.\r\n...
# 10        1.0                               Nhân viên thân thiện
# ...       ...                                                ...
# 6994      1.0  Anh chủ rất là nhiệt tình và vui vẻ, phòng sạc...
# 6995      1.0  Vị trí đẹp, mặc dù chúng tôi là khách duy nhất...
# 6996     -1.0  Không có chỗ đỗ xe, phải gửi xe ở ngoài rất tố...
# 6997      1.0  Gửi quản lý cấp cao của khách sạn, Rất tiếc hì...
# 6998      1.0   Phòng đẹp, nhân viên cực kỳ dễ thương và chu đáo
#
# [5199 rows x 2 columns]

# %%
with open('vietnamese_stopwords.txt', encoding="utf8") as f:
    stopwords = []
    for line in f:
        stopwords.append("_".join(line.strip().split()))

# %%
import re
from pyvi import ViTokenizer
def preprocessor(text):
    corpus = []
    for i in range(0, len(text)):
        review = re.sub(r"http\S+", "", str(text[i]))
        review = re.sub(r"#\S+", "", review)
        review = re.sub(r"@\S+", "", review)
        review = re.sub('[_]',' ',review)
        review = re.sub('[^a-zA-Z_áàạảãăắằặẵẳâấầẩậẫđíỉìịĩóòỏọõôốồổộỗơớờởợỡéèẹẽẻêếềểệễúùủũụưứừửựữýỳỷỹỵÁÀẢÃẠĂẮẰẲẲẶẴÂẤẦẬẪẨĐÍÌỈỊĨÓÒỎỌÕÔỐỒỔỘỖƠỚỜỞỢỠÉÈẺẸẼÊẾỀỆỂỄÚÙỦŨỤƯỨỪỬỰỮÝỲỶỴỸ]',
                        ' ',review)
        review = ViTokenizer.tokenize(review)
        review = review.lower()
        review = review.split()
        review = [word for word in review if not word in  set(stopwords)]
        review = ' '.join(review)
        corpus.append(review)
    return corpus

# %%
X = sentiment['text'].values
corpus = preprocessor(X)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect = TfidfVectorizer(analyzer='word', max_features=30000)
tfidf_vect.fit(corpus) 
X_data_tfidf =  tfidf_vect.transform(corpus)

from sklearn.model_selection import train_test_split
X = X_data_tfidf
y = sentiment['text_lb'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0)
clf.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions = clf.predict(X_test)
print('accuracy:',accuracy_score(y_test,predictions))
# Out:
# accuracy: 0.8759615384615385

# %%
from sklearn import svm
classifier = svm.SVC(probability=True)
classifier.fit(X_train, y_train)
train_predictions = classifier.predict(X_train)
predictions = classifier.predict(X_test)
print('accuracy:',accuracy_score(y_test,predictions))
print('confusion matrix:\n',confusion_matrix(y_test,predictions))
print('classification report:\n',classification_report(y_test,predictions))
# Out:
# accuracy: 0.885576923076923
# confusion matrix:
#  [[ 84 100]
#  [ 19 837]]
# classification report:
#                precision    recall  f1-score   support
#
#         -1.0       0.82      0.46      0.59       184
#          1.0       0.89      0.98      0.93       856
#
#     accuracy                           0.89      1040
#    macro avg       0.85      0.72      0.76      1040
# weighted avg       0.88      0.89      0.87      1040

# %%
X_1 = review_predict.values
corpus1 = preprocessor(X_1)
X_data_tfidf_1 =  tfidf_vect.transform(corpus1)

# %%
proba = classifier.predict_proba(X_data_tfidf_1)

# %%
df1 = pd.DataFrame(data=proba, columns=['Negative', 'Positive'])

# %%
data = pd.concat([data, df1], axis = 1).drop(columns = ['comment'])
data
# Out:
#       index                                               name    price  \
# 0         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 1         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 2         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 3         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 4         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# ...     ...                                                ...      ...
# 1978     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1979     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1980     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1981     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1982     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
#
#       number_of_comment  pin(ah)   brand  front_cam(MP)  rear_cam(MP)  weight  \
# 0                   183      NaN   Apple            8.0           NaN   495.0
# 1                   183      NaN   Apple            8.0           NaN   495.0
# 2                   183      NaN   Apple            8.0           NaN   495.0
# 3                   183      NaN   Apple            8.0           NaN   495.0
# 4                   183      NaN   Apple            8.0           NaN   495.0
# ...                 ...      ...     ...            ...           ...     ...
# 1978                165     4.75  Kindle            2.0           2.0   363.0
# 1979                165     4.75  Kindle            2.0           2.0   363.0
# 1980                165     4.75  Kindle            2.0           2.0   363.0
# 1981                165     4.75  Kindle            2.0           2.0   363.0
# 1982                165     4.75  Kindle            2.0           2.0   363.0
#
#       RAM(GB)                      screen_size  Negative  Positive
# 0         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.357961  0.642039
# 1         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.323550  0.676450
# 2         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.346554  0.653446
# 3         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.232740  0.767260
# 4         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.608760  0.391240
# ...       ...                              ...       ...       ...
# 1978      1.0        214 x 128 x 9.7 mm 8 inch  0.058020  0.941980
# 1979      1.0        214 x 128 x 9.7 mm 8 inch  0.747992  0.252008
# 1980      1.0        214 x 128 x 9.7 mm 8 inch  0.216472  0.783528
# 1981      1.0        214 x 128 x 9.7 mm 8 inch  0.168945  0.831055
# 1982      1.0        214 x 128 x 9.7 mm 8 inch  0.041679  0.958321
#
# [1983 rows x 13 columns]

# %%
group_data = data.groupby(['index', 'name', 'price', 'number_of_comment', 'pin(ah)', 'brand', 'front_cam(MP)', 'rear_cam(MP)', 'weight', 'RAM(GB)', 'screen_size'], as_index=False, dropna=False).mean()
#data.groupby(['index', 'name', 'price', 'number_of_comment'], as_index=False).mean()
group_data
# Out:
#     index                                               name     price  \
# 0       0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...   8490000
# 1       1  iPad 10.2 Inch WiFi 128GB (gen 8) New 2020 - H...  10950000
# 2       2  iPad Pro 11 inch (2020) Wifi - Hàng Nhập Khẩu ...  20490000
# 3       3  Combo Máy Đọc Sách Kindle Paperwhite Gen 10 (8...   3019000
# 4       4  iPad Air 10.9 Wi-Fi 64GB New 2020 - Hàng Chính...  15490000
# 5       5  iPad 10.2 Inch WiFi 32GB New 2019 - Hàng Nhập ...   9990000
# 6       6  iPad Air 10.9 Wi-Fi 256GB New 2020 - Hàng Chín...  18990000
# 7       7       iPad Pro 11 inch Wifi 2020 - Hàng Nhập Khẩu   22400000
# 8       8   iPad Pro 12.9 inch (2020) Wifi - Hàng Nhập Khẩu   24300000
# 9       9  iPad Air 10.5 Wi-Fi 64GB New 2019 - Nhập Khẩu ...  11990000
# 10     10  iPad 10.2 Inch WiFi 128GB New 2019 - Hàng Nhập...   9990000
# 11     11  Máy Tính Bảng Samsung Galaxy Tab A8 8" T295 - ...   3490000
# 12     12  iPad Air 10.9 Wi-Fi + Cellular 64GB New 2020 -...  18490000
# 13     13  Máy Tính Bảng Kindle Fire HD10(9th) 32GB (2019...   3245000
# 14     14  Máy Tính Bảng Samsung Galaxy Tab S6 Lite (SM-P...   7990000
# 15     15  iPad Pro 11 inch (2020) Wifi Cellular - Hàng N...  23750000
# 16     16  Máy Tính Bảng Samsung Galaxy Tab A 8 Plus P205...   5790000
# 17     17  iPad Pro 12.9 inch (2020) Wifi - Hàng Nhập Khẩ...  24990000
# 18     18  iPad 10.2 Inch WiFi 128GB (Gen 8) New 2020 - H...  11490000
# 19     19  iPad 10.2 Inch WiFi + Cellular 32GB (Gen 8) Ne...  11990000
# 20     20  iPad 10.2 Inch WiFi/Cellular 128GB New 2019 - ...  12990000
# 21     21  Máy Tính Bảng Kindle Fire 7 (9th) 16GB ( 2019)...   1349000
# 22     22  iPad 10.2 Inch WiFi + Cellular 32GB (gen 8) Ne...  10990000
# 23     23  iPad Pro 12.9 inch (2020) Wifi Cellular- Hàng ...  28990000
# 24     24  iPad 10.2 Inch WiFi/Cellular 32GB New 2019 - H...  10490000
# 25     25  Máy Tính Bảng Mobell Tab 7S (8GB) - Hàng Chính...    979000
# 26     26  Máy Tính Bảng Masstel Tab 10 Pro - Hàng Chính ...   2290000
# 27     27  Máy Tính Bảng Samsung Galaxy A 8 Plus (Có S Pe...   6990000
# 28     29     Máy Tính Bảng Masstel Tab 8 – Hàng Chính Hãng    1490000
# 29     30     Máy tính bảng Mobell Tab 10 - Hàng chính hãng    2550000
# 30     31  Máy tính bảng Vankyo MatrixPad Z4 - Hàng Chính...   2990000
# 31     32     Máy Tính Bảng Masstel Tab 7 – Hàng Chính Hãng    1400000
# 32     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...   2249000
#
#     number_of_comment  pin(ah)    brand  front_cam(MP)  rear_cam(MP)  weight  \
# 0                 183      NaN    Apple            8.0           NaN   495.0
# 1                  38      NaN    Apple            8.0           1.0   495.0
# 2                  60     2.80    Apple           12.0           7.0   471.0
# 3                  65      NaN   Kindle            NaN           NaN     NaN
# 4                  46      NaN    Apple           12.0           7.0   458.0
# 5                 419     3.20    Apple            8.0           1.0   483.0
# 6                  16      NaN    Apple           12.0           7.0   458.0
# 7                  16     2.80    Apple           12.0           7.0   471.0
# 8                   9     3.60    Apple           12.0           7.0     NaN
# 9                 277      NaN    Apple            8.0           7.0   456.0
# 10                156     3.20    Apple            8.0           1.0   483.0
# 11                282     5.10  Samsung            8.0           2.0   347.0
# 12                  6      NaN    Apple           12.0           7.0   458.0
# 13                 11     6.30   Amazon            2.0           2.0   504.0
# 14                 26     7.04  Samsung            8.0           5.0   467.0
# 15                  9     2.80    Apple           12.0           7.0   417.0
# 16                  8     4.20  Samsung            8.0           5.0   380.0
# 17                  7     3.60    Apple           12.0           7.0     NaN
# 18                 17      NaN    Apple            8.0           NaN   495.0
# 19                  3      NaN    Apple            8.0           1.0   495.0
# 20                 18     3.20    Apple            8.0           1.0   483.0
# 21                 19      NaN   Amazon            NaN           NaN    28.0
# 22                  4      NaN    Apple            8.0           1.0   495.0
# 23                  1     3.60    Apple           12.0           7.0   643.0
# 24                 14     3.20    Apple            8.0           1.0   483.0
# 25                  1     2.80   Mobell            2.0           0.0   236.0
# 26                 10     5.00  Masstel            5.0           2.0     NaN
# 27                 14     4.20  Samsung            8.0           5.0   380.0
# 28                  6     3.70  Masstel            5.0           2.0   332.0
# 29                  2      NaN   Mobell            NaN           NaN     NaN
# 30                  2      NaN   Vankyo            NaN           NaN     NaN
# 31                 25     2.80  Masstel            2.0           0.0   278.0
# 32                165     4.75   Kindle            2.0           2.0   363.0
#
#     RAM(GB)                                        screen_size  Negative  \
# 0       NaN                    250mm x 174mm X 7.5mm 10.2 inch  0.199152
# 1       NaN                          250 x 174 X 7.5 10.2 inch  0.203118
# 2       6.0   Dài 247.6 mm - Ngang 178.5 mm - Dày 5.9 mm 11...  0.209902
# 3       NaN          6.6” x 4.6” x 0.3” ( 167 x 116 x 8.18 mm)  0.278967
# 4       NaN                   247.6 x 178.5 x 6.1 mm 10.9 inch  0.240509
# 5       3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.268531
# 6       NaN  247.6 x 178.5 x 6.1 mm 10.9 inch Dài 247.6 mm ...  0.213006
# 7       6.0  dài 247.6 mm - Ngang 178.5 mm - Dày 5.9 mm 11 ...  0.165206
# 8       6.0                   280.6 x 214.9 x 5.9 mm 12.9 inch  0.203285
# 9       3.0  Dài 250.5 mm - Ngang 174.1 mm - Dày 6.1mm 10.5...  0.282282
# 10      3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.247073
# 11      2.0      Dài 210 mm - Ngang 124.4 mm - Dày 8 mm 8 inch  0.225592
# 12      NaN                   247.6 x 178.5 x 6.1 mm 10.9 inch  0.220395
# 13      2.0                                                NaN  0.220929
# 14      4.0         Dài 244.5 mm - Ngang 154.3 mm - Dày 7.0 mm  0.243021
# 15      6.0   Dài 247.6 mm - Ngang 178.5 mm - Dày 5.9 mm 11...  0.204589
# 16     32.0                                                NaN  0.161665
# 17      6.0                   280.6 x 214.9 x 5.9 mm 12.9 inch  0.180733
# 18      NaN                    250mm x 174mm X 7.5mm 10.2 inch  0.214004
# 19      NaN                    250mm x 174mm x 7.5mm 10.2 inch  0.317279
# 20      3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.184533
# 21      NaN                      Kích thước 192 x 115 x 9.6 mm  0.471217
# 22      NaN                          250 x 174 X 7.5 10.2 inch  0.142604
# 23      6.0                   280.6 x 214.9 x 5.9 mm 12.9 inch  0.218393
# 24      3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.267274
# 25      1.0     Dài 18.95cm x Rộng 10.72cm x Cao 0.85cm 7 inch  0.500000
# 26      2.0                                          10.1 inch  0.278650
# 27      3.0        Dài 212.1 - Ngang 124.1 - Dày 8.9 mm 8 inch  0.228815
# 28      1.0    (Dài x Rộng x Dày) 223mm x 123mm x 9.5mm 8 inch  0.257189
# 29      NaN                                                NaN  0.207057
# 30      2.0                                                NaN  0.395587
# 31      1.0   (Dài x Rộng x Dày) 192.3 x 109.3 x 9.5 mm 7 inch  0.279469
# 32      1.0                          214 x 128 x 9.7 mm 8 inch  0.308109
#
#     Positive
# 0   0.800848
# 1   0.796882
# 2   0.790098
# 3   0.721033
# 4   0.759491
# 5   0.731469
# 6   0.786994
# 7   0.834794
# 8   0.796715
# 9   0.717718
# 10  0.752927
# 11  0.774408
# 12  0.779605
# 13  0.779071
# 14  0.756979
# 15  0.795411
# 16  0.838335
# 17  0.819267
# 18  0.785996
# 19  0.682721
# 20  0.815467
# 21  0.528783
# 22  0.857396
# 23  0.781607
# 24  0.732726
# 25  0.500000
# 26  0.721350
# 27  0.771185
# 28  0.742811
# 29  0.792943
# 30  0.604413
# 31  0.720531
# 32  0.691891

# %%
rank_data = group_data.drop(columns=['index', 'name', 'brand', 'screen_size'])
rank_data.values
# Out:
# array([[8.49000000e+06, 1.83000000e+02,            nan, 8.00000000e+00,
#                    nan, 4.95000000e+02,            nan, 1.99152124e-01,
#         8.00847876e-01],
#        [1.09500000e+07, 3.80000000e+01,            nan, 8.00000000e+00,
#         1.00000000e+00, 4.95000000e+02,            nan, 2.03118202e-01,
#         7.96881798e-01],
#        [2.04900000e+07, 6.00000000e+01, 2.80000000e+00, 1.20000000e+01,
#         7.00000000e+00, 4.71000000e+02, 6.00000000e+00, 2.09902298e-01,
#         7.90097702e-01],
#        [3.01900000e+06, 6.50000000e+01,            nan,            nan,
#                    nan,            nan,            nan, 2.78967086e-01,
#         7.21032914e-01],
#        [1.54900000e+07, 4.60000000e+01,            nan, 1.20000000e+01,
#         7.00000000e+00, 4.58000000e+02,            nan, 2.40508925e-01,
#         7.59491075e-01],
#        [9.99000000e+06, 4.19000000e+02, 3.20000000e+00, 8.00000000e+00,
#         1.00000000e+00, 4.83000000e+02, 3.00000000e+00, 2.68531436e-01,
#         7.31468564e-01],
#        [1.89900000e+07, 1.60000000e+01,            nan, 1.20000000e+01,
#         7.00000000e+00, 4.58000000e+02,            nan, 2.13005764e-01,
#         7.86994236e-01],
#        [2.24000000e+07, 1.60000000e+01, 2.80000000e+00, 1.20000000e+01,
#         7.00000000e+00, 4.71000000e+02, 6.00000000e+00, 1.65206207e-01,
#         8.34793793e-01],
#        [2.43000000e+07, 9.00000000e+00, 3.60000000e+00, 1.20000000e+01,
#         7.00000000e+00,            nan, 6.00000000e+00, 2.03285021e-01,
#         7.96714979e-01],
#        [1.19900000e+07, 2.77000000e+02,            nan, 8.00000000e+00,
#         7.00000000e+00, 4.56000000e+02, 3.00000000e+00, 2.82281700e-01,
#         7.17718300e-01],
#        [9.99000000e+06, 1.56000000e+02, 3.20000000e+00, 8.00000000e+00,
#         1.00000000e+00, 4.83000000e+02, 3.00000000e+00, 2.47073338e-01,
#         7.52926662e-01],
#        [3.49000000e+06, 2.82000000e+02, 5.10000000e+00, 8.00000000e+00,
#         2.00000000e+00, 3.47000000e+02, 2.00000000e+00, 2.25592048e-01,
#         7.74407952e-01],
#        [1.84900000e+07, 6.00000000e+00,            nan, 1.20000000e+01,
#         7.00000000e+00, 4.58000000e+02,            nan, 2.20394945e-01,
#         7.79605055e-01],
#        [3.24500000e+06, 1.10000000e+01, 6.30000000e+00, 2.00000000e+00,
#         2.00000000e+00, 5.04000000e+02, 2.00000000e+00, 2.20928853e-01,
#         7.79071147e-01],
#        [7.99000000e+06, 2.60000000e+01, 7.04000000e+00, 8.00000000e+00,
#         5.00000000e+00, 4.67000000e+02, 4.00000000e+00, 2.43021290e-01,
#         7.56978710e-01],
#        [2.37500000e+07, 9.00000000e+00, 2.80000000e+00, 1.20000000e+01,
#         7.00000000e+00, 4.17000000e+02, 6.00000000e+00, 2.04588534e-01,
#         7.95411466e-01],
#        [5.79000000e+06, 8.00000000e+00, 4.20000000e+00, 8.00000000e+00,
#         5.00000000e+00, 3.80000000e+02, 3.20000000e+01, 1.61664705e-01,
#         8.38335295e-01],
#        [2.49900000e+07, 7.00000000e+00, 3.60000000e+00, 1.20000000e+01,
#         7.00000000e+00,            nan, 6.00000000e+00, 1.80733027e-01,
#         8.19266973e-01],
#        [1.14900000e+07, 1.70000000e+01,            nan, 8.00000000e+00,
#                    nan, 4.95000000e+02,            nan, 2.14004165e-01,
#         7.85995835e-01],
#        [1.19900000e+07, 3.00000000e+00,            nan, 8.00000000e+00,
#         1.00000000e+00, 4.95000000e+02,            nan, 3.17278823e-01,
#         6.82721177e-01],
#        [1.29900000e+07, 1.80000000e+01, 3.20000000e+00, 8.00000000e+00,
#         1.00000000e+00, 4.83000000e+02, 3.00000000e+00, 1.84532670e-01,
#         8.15467330e-01],
#        [1.34900000e+06, 1.90000000e+01,            nan,            nan,
#                    nan, 2.80000000e+01,            nan, 4.71216518e-01,
#         5.28783482e-01],
#        [1.09900000e+07, 4.00000000e+00,            nan, 8.00000000e+00,
#         1.00000000e+00, 4.95000000e+02,            nan, 1.42604231e-01,
#         8.57395769e-01],
#        [2.89900000e+07, 1.00000000e+00, 3.60000000e+00, 1.20000000e+01,
#         7.00000000e+00, 6.43000000e+02, 6.00000000e+00, 2.18393037e-01,
#         7.81606963e-01],
#        [1.04900000e+07, 1.40000000e+01, 3.20000000e+00, 8.00000000e+00,
#         1.00000000e+00, 4.83000000e+02, 3.00000000e+00, 2.67273924e-01,
#         7.32726076e-01],
#        [9.79000000e+05, 1.00000000e+00, 2.80000000e+00, 2.00000000e+00,
#         0.00000000e+00, 2.36000000e+02, 1.00000000e+00, 5.00000000e-01,
#         5.00000000e-01],
#        [2.29000000e+06, 1.00000000e+01, 5.00000000e+00, 5.00000000e+00,
#         2.00000000e+00,            nan, 2.00000000e+00, 2.78650021e-01,
#         7.21349979e-01],
#        [6.99000000e+06, 1.40000000e+01, 4.20000000e+00, 8.00000000e+00,
#         5.00000000e+00, 3.80000000e+02, 3.00000000e+00, 2.28814569e-01,
#         7.71185431e-01],
#        [1.49000000e+06, 6.00000000e+00, 3.70000000e+00, 5.00000000e+00,
#         2.00000000e+00, 3.32000000e+02, 1.00000000e+00, 2.57189033e-01,
#         7.42810967e-01],
#        [2.55000000e+06, 2.00000000e+00,            nan,            nan,
#                    nan,            nan,            nan, 2.07056810e-01,
#         7.92943190e-01],
#        [2.99000000e+06, 2.00000000e+00,            nan,            nan,
#                    nan,            nan, 2.00000000e+00, 3.95586553e-01,
#         6.04413447e-01],
#        [1.40000000e+06, 2.50000000e+01, 2.80000000e+00, 2.00000000e+00,
#         0.00000000e+00, 2.78000000e+02, 1.00000000e+00, 2.79469218e-01,
#         7.20530782e-01],
#        [2.24900000e+06, 1.65000000e+02, 4.75000000e+00, 2.00000000e+00,
#         2.00000000e+00, 3.63000000e+02, 1.00000000e+00, 3.08109375e-01,
#         6.91890625e-01]])

# %%
pd.set_option('display.max_rows', rank_data.shape[0]+1)
rank_data[lambda col :rank_data.columns] = rank_data[lambda col :rank_data.columns].replace(r'\D+', np.NaN, regex=True)
rank_data
# Out:
#          price  number_of_comment  pin(ah)  front_cam(MP)  rear_cam(MP)  \
# 0    8490000.0              183.0    4.168            8.0           2.6
# 1   10950000.0               38.0    3.968            8.0           1.0
# 2   20490000.0               60.0    2.800           12.0           7.0
# 3    3019000.0               65.0    4.970            4.4           2.0
# 4   15490000.0               46.0    3.120           12.0           7.0
# 5    9990000.0              419.0    3.200            8.0           1.0
# 6   18990000.0               16.0    3.040           12.0           7.0
# 7   22400000.0               16.0    2.800           12.0           7.0
# 8   24300000.0                9.0    3.600           12.0           7.0
# 9   11990000.0              277.0    3.968            8.0           7.0
# 10   9990000.0              156.0    3.200            8.0           1.0
# 11   3490000.0              282.0    5.100            8.0           2.0
# 12  18490000.0                6.0    3.040           12.0           7.0
# 13   3245000.0               11.0    6.300            2.0           2.0
# 14   7990000.0               26.0    7.040            8.0           5.0
# 15  23750000.0                9.0    2.800           12.0           7.0
# 16   5790000.0                8.0    4.200            8.0           5.0
# 17  24990000.0                7.0    3.600           12.0           7.0
# 18  11490000.0               17.0    3.968            8.0           2.2
# 19  11990000.0                3.0    3.968            8.0           1.0
# 20  12990000.0               18.0    3.200            8.0           1.0
# 21   1349000.0               19.0    3.810            3.2           1.2
# 22  10990000.0                4.0    3.968            8.0           1.0
# 23  28990000.0                1.0    3.600           12.0           7.0
# 24  10490000.0               14.0    3.200            8.0           1.0
# 25    979000.0                1.0    2.800            2.0           0.0
# 26   2290000.0               10.0    5.000            5.0           2.0
# 27   6990000.0               14.0    4.200            8.0           5.0
# 28   1490000.0                6.0    3.700            5.0           2.0
# 29   2550000.0                2.0    4.970            4.4           2.0
# 30   2990000.0                2.0    4.970            4.4           2.0
# 31   1400000.0               25.0    2.800            2.0           0.0
# 32   2249000.0              165.0    4.750            2.0           2.0
#
#     weight  RAM(GB)  Negative  Positive
# 0    495.0      3.2  0.199152  0.800848
# 1    495.0      3.0  0.203118  0.796882
# 2    471.0      6.0  0.209902  0.790098
# 3    364.8      1.8  0.278967  0.721033
# 4    458.0      3.6  0.240509  0.759491
# 5    483.0      3.0  0.268531  0.731469
# 6    458.0      5.4  0.213006  0.786994
# 7    471.0      6.0  0.165206  0.834794
# 8    492.0      6.0  0.203285  0.796715
# 9    456.0      3.0  0.282282  0.717718
# 10   483.0      3.0  0.247073  0.752927
# 11   347.0      2.0  0.225592  0.774408
# 12   458.0      5.4  0.220395  0.779605
# 13   504.0      2.0  0.220929  0.779071
# 14   467.0      4.0  0.243021  0.756979
# 15   417.0      6.0  0.204589  0.795411
# 16   380.0     32.0  0.161665  0.838335
# 17   492.0      6.0  0.180733  0.819267
# 18   495.0      3.0  0.214004  0.785996
# 19   495.0      3.0  0.317279  0.682721
# 20   483.0      3.0  0.184533  0.815467
# 21    28.0      1.2  0.471217  0.528783
# 22   495.0      3.0  0.142604  0.857396
# 23   643.0      6.0  0.218393  0.781607
# 24   483.0      3.0  0.267274  0.732726
# 25   236.0      1.0  0.500000  0.500000
# 26   364.8      2.0  0.278650  0.721350
# 27   380.0      3.0  0.228815  0.771185
# 28   332.0      1.0  0.257189  0.742811
# 29   364.8      1.8  0.207057  0.792943
# 30   364.8      2.0  0.395587  0.604413
# 31   278.0      1.0  0.279469  0.720531
# 32   363.0      1.0  0.308109  0.691891

# %%
from sklearn.impute import KNNImputer
data_imputed = rank_data.values
ix = [i for i in range(data_imputed.shape[1]) if i != 10]
X = data_imputed[:, ix]
imputer = KNNImputer()
imputer.fit(X)
Xtrans = imputer.transform(X)
X.shape
# Out:
# (33, 9)

# %%
rank_data = pd.DataFrame(Xtrans,index=rank_data.index, columns=rank_data.columns)

# %%
rank_data
# Out:
#          price  number_of_comment  pin(ah)  front_cam(MP)  rear_cam(MP)  \
# 0    8490000.0              183.0    4.168            8.0           2.6
# 1   10950000.0               38.0    3.968            8.0           1.0
# 2   20490000.0               60.0    2.800           12.0           7.0
# 3    3019000.0               65.0    4.970            4.4           2.0
# 4   15490000.0               46.0    3.120           12.0           7.0
# 5    9990000.0              419.0    3.200            8.0           1.0
# 6   18990000.0               16.0    3.040           12.0           7.0
# 7   22400000.0               16.0    2.800           12.0           7.0
# 8   24300000.0                9.0    3.600           12.0           7.0
# 9   11990000.0              277.0    3.968            8.0           7.0
# 10   9990000.0              156.0    3.200            8.0           1.0
# 11   3490000.0              282.0    5.100            8.0           2.0
# 12  18490000.0                6.0    3.040           12.0           7.0
# 13   3245000.0               11.0    6.300            2.0           2.0
# 14   7990000.0               26.0    7.040            8.0           5.0
# 15  23750000.0                9.0    2.800           12.0           7.0
# 16   5790000.0                8.0    4.200            8.0           5.0
# 17  24990000.0                7.0    3.600           12.0           7.0
# 18  11490000.0               17.0    3.968            8.0           2.2
# 19  11990000.0                3.0    3.968            8.0           1.0
# 20  12990000.0               18.0    3.200            8.0           1.0
# 21   1349000.0               19.0    3.810            3.2           1.2
# 22  10990000.0                4.0    3.968            8.0           1.0
# 23  28990000.0                1.0    3.600           12.0           7.0
# 24  10490000.0               14.0    3.200            8.0           1.0
# 25    979000.0                1.0    2.800            2.0           0.0
# 26   2290000.0               10.0    5.000            5.0           2.0
# 27   6990000.0               14.0    4.200            8.0           5.0
# 28   1490000.0                6.0    3.700            5.0           2.0
# 29   2550000.0                2.0    4.970            4.4           2.0
# 30   2990000.0                2.0    4.970            4.4           2.0
# 31   1400000.0               25.0    2.800            2.0           0.0
# 32   2249000.0              165.0    4.750            2.0           2.0
#
#     weight  RAM(GB)  Negative  Positive
# 0    495.0      3.2  0.199152  0.800848
# 1    495.0      3.0  0.203118  0.796882
# 2    471.0      6.0  0.209902  0.790098
# 3    364.8      1.8  0.278967  0.721033
# 4    458.0      3.6  0.240509  0.759491
# 5    483.0      3.0  0.268531  0.731469
# 6    458.0      5.4  0.213006  0.786994
# 7    471.0      6.0  0.165206  0.834794
# 8    492.0      6.0  0.203285  0.796715
# 9    456.0      3.0  0.282282  0.717718
# 10   483.0      3.0  0.247073  0.752927
# 11   347.0      2.0  0.225592  0.774408
# 12   458.0      5.4  0.220395  0.779605
# 13   504.0      2.0  0.220929  0.779071
# 14   467.0      4.0  0.243021  0.756979
# 15   417.0      6.0  0.204589  0.795411
# 16   380.0     32.0  0.161665  0.838335
# 17   492.0      6.0  0.180733  0.819267
# 18   495.0      3.0  0.214004  0.785996
# 19   495.0      3.0  0.317279  0.682721
# 20   483.0      3.0  0.184533  0.815467
# 21    28.0      1.2  0.471217  0.528783
# 22   495.0      3.0  0.142604  0.857396
# 23   643.0      6.0  0.218393  0.781607
# 24   483.0      3.0  0.267274  0.732726
# 25   236.0      1.0  0.500000  0.500000
# 26   364.8      2.0  0.278650  0.721350
# 27   380.0      3.0  0.228815  0.771185
# 28   332.0      1.0  0.257189  0.742811
# 29   364.8      1.8  0.207057  0.792943
# 30   364.8      2.0  0.395587  0.604413
# 31   278.0      1.0  0.279469  0.720531
# 32   363.0      1.0  0.308109  0.691891

# %%
from sklearn.preprocessing import StandardScaler

Standard_scaler = StandardScaler()
Xtrans = Standard_scaler.fit_transform(Xtrans)

# %%
rank_data_scaled = pd.DataFrame(Xtrans,index=rank_data.index, columns=rank_data.columns)

# %%
from skcriteria import Data, MIN, MAX
ranking = Data(
    rank_data_scaled,
    [MIN, MAX, MAX, MAX, MAX, MIN, MAX, MIN, MAX],
    cnames = rank_data.columns,
    weights = [1,1,1,1,1,1,1,100,1]
)

# %%
from skcriteria.madm import simple
dm = simple.WeightedSum(mnorm = "sum",wnorm = "sum")
dec = dm.decide(ranking)

# %%
rank_data['rank'] = dec.rank_
rank_data.sort_values(by=['rank'])
# Out:
#          price  number_of_comment  pin(ah)  front_cam(MP)  rear_cam(MP)  \
# 4   15490000.0               46.0    3.120           12.0           7.0
# 12  18490000.0                6.0    3.040           12.0           7.0
# 6   18990000.0               16.0    3.040           12.0           7.0
# 23  28990000.0                1.0    3.600           12.0           7.0
# 15  23750000.0                9.0    2.800           12.0           7.0
# 8   24300000.0                9.0    3.600           12.0           7.0
# 17  24990000.0                7.0    3.600           12.0           7.0
# 7   22400000.0               16.0    2.800           12.0           7.0
# 2   20490000.0               60.0    2.800           12.0           7.0
# 27   6990000.0               14.0    4.200            8.0           5.0
# 14   7990000.0               26.0    7.040            8.0           5.0
# 9   11990000.0              277.0    3.968            8.0           7.0
# 28   1490000.0                6.0    3.700            5.0           2.0
# 18  11490000.0               17.0    3.968            8.0           2.2
# 30   2990000.0                2.0    4.970            4.4           2.0
# 26   2290000.0               10.0    5.000            5.0           2.0
# 29   2550000.0                2.0    4.970            4.4           2.0
# 21   1349000.0               19.0    3.810            3.2           1.2
# 19  11990000.0                3.0    3.968            8.0           1.0
# 24  10490000.0               14.0    3.200            8.0           1.0
# 3    3019000.0               65.0    4.970            4.4           2.0
# 13   3245000.0               11.0    6.300            2.0           2.0
# 20  12990000.0               18.0    3.200            8.0           1.0
# 22  10990000.0                4.0    3.968            8.0           1.0
# 1   10950000.0               38.0    3.968            8.0           1.0
# 0    8490000.0              183.0    4.168            8.0           2.6
# 25    979000.0                1.0    2.800            2.0           0.0
# 32   2249000.0              165.0    4.750            2.0           2.0
# 31   1400000.0               25.0    2.800            2.0           0.0
# 10   9990000.0              156.0    3.200            8.0           1.0
# 11   3490000.0              282.0    5.100            8.0           2.0
# 16   5790000.0                8.0    4.200            8.0           5.0
# 5    9990000.0              419.0    3.200            8.0           1.0
#
#     weight  RAM(GB)  Negative  Positive  rank
# 4    458.0      3.6  0.240509  0.759491     1
# 12   458.0      5.4  0.220395  0.779605     2
# 6    458.0      5.4  0.213006  0.786994     3
# 23   643.0      6.0  0.218393  0.781607     4
# 15   417.0      6.0  0.204589  0.795411     5
# 8    492.0      6.0  0.203285  0.796715     6
# 17   492.0      6.0  0.180733  0.819267     7
# 7    471.0      6.0  0.165206  0.834794     8
# 2    471.0      6.0  0.209902  0.790098     9
# 27   380.0      3.0  0.228815  0.771185    10
# 14   467.0      4.0  0.243021  0.756979    11
# 9    456.0      3.0  0.282282  0.717718    12
# 28   332.0      1.0  0.257189  0.742811    13
# 18   495.0      3.0  0.214004  0.785996    14
# 30   364.8      2.0  0.395587  0.604413    15
# 26   364.8      2.0  0.278650  0.721350    16
# 29   364.8      1.8  0.207057  0.792943    17
# 21    28.0      1.2  0.471217  0.528783    18
# 19   495.0      3.0  0.317279  0.682721    19
# 24   483.0      3.0  0.267274  0.732726    20
# 3    364.8      1.8  0.278967  0.721033    21
# 13   504.0      2.0  0.220929  0.779071    22
# 20   483.0      3.0  0.184533  0.815467    23
# 22   495.0      3.0  0.142604  0.857396    24
# 1    495.0      3.0  0.203118  0.796882    25
# 0    495.0      3.2  0.199152  0.800848    26
# 25   236.0      1.0  0.500000  0.500000    27
# 32   363.0      1.0  0.308109  0.691891    28
# 31   278.0      1.0  0.279469  0.720531    29
# 10   483.0      3.0  0.247073  0.752927    30
# 11   347.0      2.0  0.225592  0.774408    31
# 16   380.0     32.0  0.161665  0.838335    32
# 5    483.0      3.0  0.268531  0.731469    33

# %%
cols_to_keep = ['index', 'name', 'brand']
group_data = group_data.drop(group_data.columns.difference(cols_to_keep), axis=1)

# %%
pd.concat([group_data, rank_data], axis=1, join="inner").to_csv('tablet_done.csv')
