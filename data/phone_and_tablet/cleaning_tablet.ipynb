# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("tablet.csv")
data
# Out:
#       index                                               name    price  \
# 0         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 1         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 2         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 3         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 4         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# ...     ...                                                ...      ...
# 1978     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1979     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1980     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1981     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1982     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
#
#       number_of_comment  pin(ah)   brand  front_cam(MP)  rear_cam(MP)  weight  \
# 0                   183      NaN   Apple            8.0           NaN   495.0
# 1                   183      NaN   Apple            8.0           NaN   495.0
# 2                   183      NaN   Apple            8.0           NaN   495.0
# 3                   183      NaN   Apple            8.0           NaN   495.0
# 4                   183      NaN   Apple            8.0           NaN   495.0
# ...                 ...      ...     ...            ...           ...     ...
# 1978                165     4.75  Kindle            2.0           2.0   363.0
# 1979                165     4.75  Kindle            2.0           2.0   363.0
# 1980                165     4.75  Kindle            2.0           2.0   363.0
# 1981                165     4.75  Kindle            2.0           2.0   363.0
# 1982                165     4.75  Kindle            2.0           2.0   363.0
#
#       RAM(GB)                      screen_size  \
# 0         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 1         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 2         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 3         NaN  250mm x 174mm X 7.5mm 10.2 inch
# 4         NaN  250mm x 174mm X 7.5mm 10.2 inch
# ...       ...                              ...
# 1978      1.0        214 x 128 x 9.7 mm 8 inch
# 1979      1.0        214 x 128 x 9.7 mm 8 inch
# 1980      1.0        214 x 128 x 9.7 mm 8 inch
# 1981      1.0        214 x 128 x 9.7 mm 8 inch
# 1982      1.0        214 x 128 x 9.7 mm 8 inch
#
#                                                 comment
# 0     Mình đặt lúc 17h30 chiều và 20h tối nhận máy m...
# 1     Mua cho người già sử dụng nên con này là đủ vớ...
# 2     Hàng chính hãng nguyên seal chưa active giao n...
# 3     Hàng chính hãng nguyên seal chưa kích hoạt mã ...
# 4     Mình cho 3 sao là bởi vì 1 Sản phẩm giá trị ca...
# ...                                                 ...
# 1978             Đáng đồng tiền bỏ ra Không mong gì hơn
# 1979  Không nên mua bởi vì tôi mua máy chạy rất chậm...
# 1980  Máy dùng tạm được màn hình chất lượng thấp mờ ...
# 1981  Đây là lựa chọn tốt trong tầm giá tiền dưới 2 ...
# 1982                                                NaN
#
# [1983 rows x 12 columns]

# %%
review_predict = data['comment']

# %%
sentiment = pd.read_csv('text.csv',index_col=[0])
sentiment
# Out:
#       text_lb                                               text
# 2         1.0     Ấn tượng, tôi sẽ quay lại vào dịp nghỉ lần sau
# 3         1.0  Quá tuyệt vời , view đẹp , chủ nhà thân thiện ...
# 6         1.0  Phòng nghỉ đáng giá, tiện nghi cơ bản đầy đủ ^...
# 7         1.0  Thuận tiện cho việc đi thăm thú cảnh quan.\nBạ...
# 10        1.0                               Nhân viên thân thiện
# ...       ...                                                ...
# 6994      1.0  Anh chủ rất là nhiệt tình và vui vẻ, phòng sạc...
# 6995      1.0  Vị trí đẹp, mặc dù chúng tôi là khách duy nhất...
# 6996     -1.0  Không có chỗ đỗ xe, phải gửi xe ở ngoài rất tố...
# 6997      1.0  Gửi quản lý cấp cao của khách sạn, Rất tiếc hì...
# 6998      1.0   Phòng đẹp, nhân viên cực kỳ dễ thương và chu đáo
#
# [5199 rows x 2 columns]

# %%
with open('vietnamese_stopwords.txt', encoding="utf8") as f:
    stopwords = []
    for line in f:
        stopwords.append("_".join(line.strip().split()))

# %%
import re
from pyvi import ViTokenizer
def preprocessor(text):
    corpus = []
    for i in range(0, len(text)):
        review = re.sub(r"http\S+", "", str(text[i]))
        review = re.sub(r"#\S+", "", review)
        review = re.sub(r"@\S+", "", review)
        review = re.sub('[_]',' ',review)
        review = re.sub('[^a-zA-Z_áàạảãăắằặẵẳâấầẩậẫđíỉìịĩóòỏọõôốồổộỗơớờởợỡéèẹẽẻêếềểệễúùủũụưứừửựữýỳỷỹỵÁÀẢÃẠĂẮẰẲẲẶẴÂẤẦẬẪẨĐÍÌỈỊĨÓÒỎỌÕÔỐỒỔỘỖƠỚỜỞỢỠÉÈẺẸẼÊẾỀỆỂỄÚÙỦŨỤƯỨỪỬỰỮÝỲỶỴỸ]',
                        ' ',review)
        review = ViTokenizer.tokenize(review)
        review = review.lower()
        review = review.split()
        review = [word for word in review if not word in  set(stopwords)]
        review = ' '.join(review)
        corpus.append(review)
    return corpus

# %%
X = sentiment['text'].values
corpus = preprocessor(X)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect = TfidfVectorizer(analyzer='word', max_features=30000)
tfidf_vect.fit(corpus) 
X_data_tfidf =  tfidf_vect.transform(corpus)

from sklearn.model_selection import train_test_split
X = X_data_tfidf
y = sentiment['text_lb'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0)
clf.fit(X_train, y_train)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
predictions = clf.predict(X_test)
print('accuracy:',accuracy_score(y_test,predictions))
# Out:
# accuracy: 0.8759615384615385

# %%
from sklearn import svm
classifier = svm.SVC(probability=True)
classifier.fit(X_train, y_train)
train_predictions = classifier.predict(X_train)
predictions = classifier.predict(X_test)
print('accuracy:',accuracy_score(y_test,predictions))
print('confusion matrix:\n',confusion_matrix(y_test,predictions))
print('classification report:\n',classification_report(y_test,predictions))
# Out:
# accuracy: 0.885576923076923
# confusion matrix:
#  [[ 84 100]
#  [ 19 837]]
# classification report:
#                precision    recall  f1-score   support
#
#         -1.0       0.82      0.46      0.59       184
#          1.0       0.89      0.98      0.93       856
#
#     accuracy                           0.89      1040
#    macro avg       0.85      0.72      0.76      1040
# weighted avg       0.88      0.89      0.87      1040

# %%
X_1 = review_predict.values
corpus1 = preprocessor(X_1)
X_data_tfidf_1 =  tfidf_vect.transform(corpus1)

# %%
proba = classifier.predict_proba(X_data_tfidf_1)

# %%
df1 = pd.DataFrame(data=proba, columns=['Negative', 'Positive'])

# %%
data = pd.concat([data, df1], axis = 1).drop(columns = ['comment'])
data
# Out:
#       index                                               name    price  \
# 0         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 1         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 2         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 3         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# 4         0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...  8490000
# ...     ...                                                ...      ...
# 1978     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1979     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1980     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1981     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
# 1982     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...  2249000
#
#       number_of_comment  pin(ah)   brand  front_cam(MP)  rear_cam(MP)  weight  \
# 0                   183      NaN   Apple            8.0           NaN   495.0
# 1                   183      NaN   Apple            8.0           NaN   495.0
# 2                   183      NaN   Apple            8.0           NaN   495.0
# 3                   183      NaN   Apple            8.0           NaN   495.0
# 4                   183      NaN   Apple            8.0           NaN   495.0
# ...                 ...      ...     ...            ...           ...     ...
# 1978                165     4.75  Kindle            2.0           2.0   363.0
# 1979                165     4.75  Kindle            2.0           2.0   363.0
# 1980                165     4.75  Kindle            2.0           2.0   363.0
# 1981                165     4.75  Kindle            2.0           2.0   363.0
# 1982                165     4.75  Kindle            2.0           2.0   363.0
#
#       RAM(GB)                      screen_size  Negative  Positive
# 0         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.360156  0.639844
# 1         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.324529  0.675471
# 2         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.348160  0.651840
# 3         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.231485  0.768515
# 4         NaN  250mm x 174mm X 7.5mm 10.2 inch  0.616682  0.383318
# ...       ...                              ...       ...       ...
# 1978      1.0        214 x 128 x 9.7 mm 8 inch  0.055491  0.944509
# 1979      1.0        214 x 128 x 9.7 mm 8 inch  0.757412  0.242588
# 1980      1.0        214 x 128 x 9.7 mm 8 inch  0.214881  0.785119
# 1981      1.0        214 x 128 x 9.7 mm 8 inch  0.166546  0.833454
# 1982      1.0        214 x 128 x 9.7 mm 8 inch  0.039497  0.960503
#
# [1983 rows x 13 columns]

# %%
group_data = data.groupby(['index', 'name', 'price', 'number_of_comment', 'pin(ah)', 'brand', 'front_cam(MP)', 'rear_cam(MP)', 'weight', 'RAM(GB)', 'screen_size'], as_index=False, dropna=False).mean()
group_data['rank_point'] = group_data.number_of_comment * group_data.Positive
group_data
# Out:
#     index                                               name     price  \
# 0       0  iPad 10.2 Inch WiFi 32GB (Gen 8) New 2020 - Hà...   8490000
# 1       1  iPad 10.2 Inch WiFi 128GB (gen 8) New 2020 - H...  10950000
# 2       2  iPad Pro 11 inch (2020) Wifi - Hàng Nhập Khẩu ...  20490000
# 3       3  Combo Máy Đọc Sách Kindle Paperwhite Gen 10 (8...   3019000
# 4       4  iPad Air 10.9 Wi-Fi 64GB New 2020 - Hàng Chính...  15490000
# 5       5  iPad 10.2 Inch WiFi 32GB New 2019 - Hàng Nhập ...   9990000
# 6       6  iPad Air 10.9 Wi-Fi 256GB New 2020 - Hàng Chín...  18990000
# 7       7       iPad Pro 11 inch Wifi 2020 - Hàng Nhập Khẩu   22400000
# 8       8   iPad Pro 12.9 inch (2020) Wifi - Hàng Nhập Khẩu   24300000
# 9       9  iPad Air 10.5 Wi-Fi 64GB New 2019 - Nhập Khẩu ...  11990000
# 10     10  iPad 10.2 Inch WiFi 128GB New 2019 - Hàng Nhập...   9990000
# 11     11  Máy Tính Bảng Samsung Galaxy Tab A8 8" T295 - ...   3490000
# 12     12  iPad Air 10.9 Wi-Fi + Cellular 64GB New 2020 -...  18490000
# 13     13  Máy Tính Bảng Kindle Fire HD10(9th) 32GB (2019...   3245000
# 14     14  Máy Tính Bảng Samsung Galaxy Tab S6 Lite (SM-P...   7990000
# 15     15  iPad Pro 11 inch (2020) Wifi Cellular - Hàng N...  23750000
# 16     16  Máy Tính Bảng Samsung Galaxy Tab A 8 Plus P205...   5790000
# 17     17  iPad Pro 12.9 inch (2020) Wifi - Hàng Nhập Khẩ...  24990000
# 18     18  iPad 10.2 Inch WiFi 128GB (Gen 8) New 2020 - H...  11490000
# 19     19  iPad 10.2 Inch WiFi + Cellular 32GB (Gen 8) Ne...  11990000
# 20     20  iPad 10.2 Inch WiFi/Cellular 128GB New 2019 - ...  12990000
# 21     21  Máy Tính Bảng Kindle Fire 7 (9th) 16GB ( 2019)...   1349000
# 22     22  iPad 10.2 Inch WiFi + Cellular 32GB (gen 8) Ne...  10990000
# 23     23  iPad Pro 12.9 inch (2020) Wifi Cellular- Hàng ...  28990000
# 24     24  iPad 10.2 Inch WiFi/Cellular 32GB New 2019 - H...  10490000
# 25     25  Máy Tính Bảng Mobell Tab 7S (8GB) - Hàng Chính...    979000
# 26     26  Máy Tính Bảng Masstel Tab 10 Pro - Hàng Chính ...   2290000
# 27     27  Máy Tính Bảng Samsung Galaxy A 8 Plus (Có S Pe...   6990000
# 28     29     Máy Tính Bảng Masstel Tab 8 – Hàng Chính Hãng    1490000
# 29     30     Máy tính bảng Mobell Tab 10 - Hàng chính hãng    2550000
# 30     31  Máy tính bảng Vankyo MatrixPad Z4 - Hàng Chính...   2990000
# 31     32     Máy Tính Bảng Masstel Tab 7 – Hàng Chính Hãng    1400000
# 32     34  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...   2249000
#
#     number_of_comment  pin(ah)    brand  front_cam(MP)  rear_cam(MP)  weight  \
# 0                 183      NaN    Apple            8.0           NaN   495.0
# 1                  38      NaN    Apple            8.0           1.0   495.0
# 2                  60     2.80    Apple           12.0           7.0   471.0
# 3                  65      NaN   Kindle            NaN           NaN     NaN
# 4                  46      NaN    Apple           12.0           7.0   458.0
# 5                 419     3.20    Apple            8.0           1.0   483.0
# 6                  16      NaN    Apple           12.0           7.0   458.0
# 7                  16     2.80    Apple           12.0           7.0   471.0
# 8                   9     3.60    Apple           12.0           7.0     NaN
# 9                 277      NaN    Apple            8.0           7.0   456.0
# 10                156     3.20    Apple            8.0           1.0   483.0
# 11                282     5.10  Samsung            8.0           2.0   347.0
# 12                  6      NaN    Apple           12.0           7.0   458.0
# 13                 11     6.30   Amazon            2.0           2.0   504.0
# 14                 26     7.04  Samsung            8.0           5.0   467.0
# 15                  9     2.80    Apple           12.0           7.0   417.0
# 16                  8     4.20  Samsung            8.0           5.0   380.0
# 17                  7     3.60    Apple           12.0           7.0     NaN
# 18                 17      NaN    Apple            8.0           NaN   495.0
# 19                  3      NaN    Apple            8.0           1.0   495.0
# 20                 18     3.20    Apple            8.0           1.0   483.0
# 21                 19      NaN   Amazon            NaN           NaN    28.0
# 22                  4      NaN    Apple            8.0           1.0   495.0
# 23                  1     3.60    Apple           12.0           7.0   643.0
# 24                 14     3.20    Apple            8.0           1.0   483.0
# 25                  1     2.80   Mobell            2.0           0.0   236.0
# 26                 10     5.00  Masstel            5.0           2.0     NaN
# 27                 14     4.20  Samsung            8.0           5.0   380.0
# 28                  6     3.70  Masstel            5.0           2.0   332.0
# 29                  2      NaN   Mobell            NaN           NaN     NaN
# 30                  2      NaN   Vankyo            NaN           NaN     NaN
# 31                 25     2.80  Masstel            2.0           0.0   278.0
# 32                165     4.75   Kindle            2.0           2.0   363.0
#
#     RAM(GB)                                        screen_size  Negative  \
# 0       NaN                    250mm x 174mm X 7.5mm 10.2 inch  0.197811
# 1       NaN                          250 x 174 X 7.5 10.2 inch  0.202002
# 2       6.0   Dài 247.6 mm - Ngang 178.5 mm - Dày 5.9 mm 11...  0.209096
# 3       NaN          6.6” x 4.6” x 0.3” ( 167 x 116 x 8.18 mm)  0.279386
# 4       NaN                   247.6 x 178.5 x 6.1 mm 10.9 inch  0.240241
# 5       3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.268821
# 6       NaN  247.6 x 178.5 x 6.1 mm 10.9 inch Dài 247.6 mm ...  0.211150
# 7       6.0  dài 247.6 mm - Ngang 178.5 mm - Dày 5.9 mm 11 ...  0.163159
# 8       6.0                   280.6 x 214.9 x 5.9 mm 12.9 inch  0.202142
# 9       3.0  Dài 250.5 mm - Ngang 174.1 mm - Dày 6.1mm 10.5...  0.282797
# 10      3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.246979
# 11      2.0      Dài 210 mm - Ngang 124.4 mm - Dày 8 mm 8 inch  0.225010
# 12      NaN                   247.6 x 178.5 x 6.1 mm 10.9 inch  0.219901
# 13      2.0                                                NaN  0.220375
# 14      4.0         Dài 244.5 mm - Ngang 154.3 mm - Dày 7.0 mm  0.242749
# 15      6.0   Dài 247.6 mm - Ngang 178.5 mm - Dày 5.9 mm 11...  0.203233
# 16     32.0                                                NaN  0.159360
# 17      6.0                   280.6 x 214.9 x 5.9 mm 12.9 inch  0.178851
# 18      NaN                    250mm x 174mm X 7.5mm 10.2 inch  0.213077
# 19      NaN                    250mm x 174mm x 7.5mm 10.2 inch  0.318319
# 20      3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.183158
# 21      NaN                      Kích thước 192 x 115 x 9.6 mm  0.476074
# 22      NaN                          250 x 174 X 7.5 10.2 inch  0.140572
# 23      6.0                   280.6 x 214.9 x 5.9 mm 12.9 inch  0.216840
# 24      3.0  250.6 x 174.1 x 7.5 mm (9.87 x 6.85 x 0.30 in)...  0.267562
# 25      1.0     Dài 18.95cm x Rộng 10.72cm x Cao 0.85cm 7 inch  0.500000
# 26      2.0                                          10.1 inch  0.279447
# 27      3.0        Dài 212.1 - Ngang 124.1 - Dày 8.9 mm 8 inch  0.227780
# 28      1.0    (Dài x Rộng x Dày) 223mm x 123mm x 9.5mm 8 inch  0.257213
# 29      NaN                                                NaN  0.205976
# 30      2.0                                                NaN  0.398410
# 31      1.0   (Dài x Rộng x Dày) 192.3 x 109.3 x 9.5 mm 7 inch  0.280106
# 32      1.0                          214 x 128 x 9.7 mm 8 inch  0.309122
#
#     Positive  rank_point
# 0   0.802189  146.800607
# 1   0.797998   30.323938
# 2   0.790904   47.454220
# 3   0.720614   46.839933
# 4   0.759759   34.948919
# 5   0.731179  306.364087
# 6   0.788850   12.621598
# 7   0.836841   13.389456
# 8   0.797858    7.180719
# 9   0.717203  198.665099
# 10  0.753021  117.471330
# 11  0.774990  218.547077
# 12  0.780099    4.680595
# 13  0.779625    8.575874
# 14  0.757251   19.688527
# 15  0.796767    7.170901
# 16  0.840640    6.725116
# 17  0.821149    5.748044
# 18  0.786923   13.377699
# 19  0.681681    2.045043
# 20  0.816842   14.703157
# 21  0.523926    9.954593
# 22  0.859428    3.437712
# 23  0.783160    0.783160
# 24  0.732438   10.254126
# 25  0.500000    0.500000
# 26  0.720553    7.205533
# 27  0.772220   10.811081
# 28  0.742787    4.456724
# 29  0.794024    1.588047
# 30  0.601590    1.203179
# 31  0.719894   17.997359
# 32  0.690878  113.994853

# %%
rank_data = group_data.drop(columns=['index', 'name', 'brand', 'screen_size', 'number_of_comment', 'Negative', 'Positive'])
rank_data.values
# Out:
# array([[8.49000000e+06,            nan, 8.00000000e+00,            nan,
#         4.95000000e+02,            nan, 1.46800607e+02],
#        [1.09500000e+07,            nan, 8.00000000e+00, 1.00000000e+00,
#         4.95000000e+02,            nan, 3.03239383e+01],
#        [2.04900000e+07, 2.80000000e+00, 1.20000000e+01, 7.00000000e+00,
#         4.71000000e+02, 6.00000000e+00, 4.74542199e+01],
#        [3.01900000e+06,            nan,            nan,            nan,
#                    nan,            nan, 4.68399334e+01],
#        [1.54900000e+07,            nan, 1.20000000e+01, 7.00000000e+00,
#         4.58000000e+02,            nan, 3.49489186e+01],
#        [9.99000000e+06, 3.20000000e+00, 8.00000000e+00, 1.00000000e+00,
#         4.83000000e+02, 3.00000000e+00, 3.06364087e+02],
#        [1.89900000e+07,            nan, 1.20000000e+01, 7.00000000e+00,
#         4.58000000e+02,            nan, 1.26215981e+01],
#        [2.24000000e+07, 2.80000000e+00, 1.20000000e+01, 7.00000000e+00,
#         4.71000000e+02, 6.00000000e+00, 1.33894557e+01],
#        [2.43000000e+07, 3.60000000e+00, 1.20000000e+01, 7.00000000e+00,
#                    nan, 6.00000000e+00, 7.18071895e+00],
#        [1.19900000e+07,            nan, 8.00000000e+00, 7.00000000e+00,
#         4.56000000e+02, 3.00000000e+00, 1.98665099e+02],
#        [9.99000000e+06, 3.20000000e+00, 8.00000000e+00, 1.00000000e+00,
#         4.83000000e+02, 3.00000000e+00, 1.17471330e+02],
#        [3.49000000e+06, 5.10000000e+00, 8.00000000e+00, 2.00000000e+00,
#         3.47000000e+02, 2.00000000e+00, 2.18547077e+02],
#        [1.84900000e+07,            nan, 1.20000000e+01, 7.00000000e+00,
#         4.58000000e+02,            nan, 4.68059544e+00],
#        [3.24500000e+06, 6.30000000e+00, 2.00000000e+00, 2.00000000e+00,
#         5.04000000e+02, 2.00000000e+00, 8.57587370e+00],
#        [7.99000000e+06, 7.04000000e+00, 8.00000000e+00, 5.00000000e+00,
#         4.67000000e+02, 4.00000000e+00, 1.96885272e+01],
#        [2.37500000e+07, 2.80000000e+00, 1.20000000e+01, 7.00000000e+00,
#         4.17000000e+02, 6.00000000e+00, 7.17090066e+00],
#        [5.79000000e+06, 4.20000000e+00, 8.00000000e+00, 5.00000000e+00,
#         3.80000000e+02, 3.20000000e+01, 6.72511615e+00],
#        [2.49900000e+07, 3.60000000e+00, 1.20000000e+01, 7.00000000e+00,
#                    nan, 6.00000000e+00, 5.74804395e+00],
#        [1.14900000e+07,            nan, 8.00000000e+00,            nan,
#         4.95000000e+02,            nan, 1.33776995e+01],
#        [1.19900000e+07,            nan, 8.00000000e+00, 1.00000000e+00,
#         4.95000000e+02,            nan, 2.04504301e+00],
#        [1.29900000e+07, 3.20000000e+00, 8.00000000e+00, 1.00000000e+00,
#         4.83000000e+02, 3.00000000e+00, 1.47031566e+01],
#        [1.34900000e+06,            nan,            nan,            nan,
#         2.80000000e+01,            nan, 9.95459285e+00],
#        [1.09900000e+07,            nan, 8.00000000e+00, 1.00000000e+00,
#         4.95000000e+02,            nan, 3.43771199e+00],
#        [2.89900000e+07, 3.60000000e+00, 1.20000000e+01, 7.00000000e+00,
#         6.43000000e+02, 6.00000000e+00, 7.83159974e-01],
#        [1.04900000e+07, 3.20000000e+00, 8.00000000e+00, 1.00000000e+00,
#         4.83000000e+02, 3.00000000e+00, 1.02541265e+01],
#        [9.79000000e+05, 2.80000000e+00, 2.00000000e+00, 0.00000000e+00,
#         2.36000000e+02, 1.00000000e+00, 5.00000000e-01],
#        [2.29000000e+06, 5.00000000e+00, 5.00000000e+00, 2.00000000e+00,
#                    nan, 2.00000000e+00, 7.20553342e+00],
#        [6.99000000e+06, 4.20000000e+00, 8.00000000e+00, 5.00000000e+00,
#         3.80000000e+02, 3.00000000e+00, 1.08110809e+01],
#        [1.49000000e+06, 3.70000000e+00, 5.00000000e+00, 2.00000000e+00,
#         3.32000000e+02, 1.00000000e+00, 4.45672377e+00],
#        [2.55000000e+06,            nan,            nan,            nan,
#                    nan,            nan, 1.58804719e+00],
#        [2.99000000e+06,            nan,            nan,            nan,
#                    nan, 2.00000000e+00, 1.20317923e+00],
#        [1.40000000e+06, 2.80000000e+00, 2.00000000e+00, 0.00000000e+00,
#         2.78000000e+02, 1.00000000e+00, 1.79973587e+01],
#        [2.24900000e+06, 4.75000000e+00, 2.00000000e+00, 2.00000000e+00,
#         3.63000000e+02, 1.00000000e+00, 1.13994853e+02]])

# %%
pd.set_option('display.max_rows', rank_data.shape[0]+1)
rank_data[lambda col :rank_data.columns] = rank_data[lambda col :rank_data.columns].replace(r'\D+', np.NaN, regex=True)
rank_data
# Out:
#        price  pin(ah)  front_cam(MP)  rear_cam(MP)  weight  RAM(GB)  \
# 0    8490000      NaN            8.0           NaN   495.0      NaN
# 1   10950000      NaN            8.0           1.0   495.0      NaN
# 2   20490000     2.80           12.0           7.0   471.0      6.0
# 3    3019000      NaN            NaN           NaN     NaN      NaN
# 4   15490000      NaN           12.0           7.0   458.0      NaN
# 5    9990000     3.20            8.0           1.0   483.0      3.0
# 6   18990000      NaN           12.0           7.0   458.0      NaN
# 7   22400000     2.80           12.0           7.0   471.0      6.0
# 8   24300000     3.60           12.0           7.0     NaN      6.0
# 9   11990000      NaN            8.0           7.0   456.0      3.0
# 10   9990000     3.20            8.0           1.0   483.0      3.0
# 11   3490000     5.10            8.0           2.0   347.0      2.0
# 12  18490000      NaN           12.0           7.0   458.0      NaN
# 13   3245000     6.30            2.0           2.0   504.0      2.0
# 14   7990000     7.04            8.0           5.0   467.0      4.0
# 15  23750000     2.80           12.0           7.0   417.0      6.0
# 16   5790000     4.20            8.0           5.0   380.0     32.0
# 17  24990000     3.60           12.0           7.0     NaN      6.0
# 18  11490000      NaN            8.0           NaN   495.0      NaN
# 19  11990000      NaN            8.0           1.0   495.0      NaN
# 20  12990000     3.20            8.0           1.0   483.0      3.0
# 21   1349000      NaN            NaN           NaN    28.0      NaN
# 22  10990000      NaN            8.0           1.0   495.0      NaN
# 23  28990000     3.60           12.0           7.0   643.0      6.0
# 24  10490000     3.20            8.0           1.0   483.0      3.0
# 25    979000     2.80            2.0           0.0   236.0      1.0
# 26   2290000     5.00            5.0           2.0     NaN      2.0
# 27   6990000     4.20            8.0           5.0   380.0      3.0
# 28   1490000     3.70            5.0           2.0   332.0      1.0
# 29   2550000      NaN            NaN           NaN     NaN      NaN
# 30   2990000      NaN            NaN           NaN     NaN      2.0
# 31   1400000     2.80            2.0           0.0   278.0      1.0
# 32   2249000     4.75            2.0           2.0   363.0      1.0
#
#     rank_point
# 0   146.800607
# 1    30.323938
# 2    47.454220
# 3    46.839933
# 4    34.948919
# 5   306.364087
# 6    12.621598
# 7    13.389456
# 8     7.180719
# 9   198.665099
# 10  117.471330
# 11  218.547077
# 12    4.680595
# 13    8.575874
# 14   19.688527
# 15    7.170901
# 16    6.725116
# 17    5.748044
# 18   13.377699
# 19    2.045043
# 20   14.703157
# 21    9.954593
# 22    3.437712
# 23    0.783160
# 24   10.254126
# 25    0.500000
# 26    7.205533
# 27   10.811081
# 28    4.456724
# 29    1.588047
# 30    1.203179
# 31   17.997359
# 32  113.994853

# %%
from sklearn.impute import KNNImputer
data_imputed = rank_data.values
ix = [i for i in range(data_imputed.shape[1]) if i != len(rank_data.columns)]
X = data_imputed[:, ix]
imputer = KNNImputer(n_neighbors=len(rank_data.columns))
imputer.fit(X)
Xtrans = imputer.transform(X)
X.shape
# Out:
# (33, 7)

# %%
rank_data = pd.DataFrame(Xtrans,index=rank_data.index, columns=rank_data.columns)

# %%
rank_data
# Out:
#          price   pin(ah)  front_cam(MP)  rear_cam(MP)      weight    RAM(GB)  \
# 0    8490000.0  4.034286       8.000000      2.142857  495.000000   7.285714
# 1   10950000.0  4.034286       8.000000      1.000000  495.000000   3.142857
# 2   20490000.0  2.800000      12.000000      7.000000  471.000000   6.000000
# 3    3019000.0  4.350000       3.714286      1.428571  298.285714   1.571429
# 4   15490000.0  3.634286      12.000000      7.000000  458.000000   3.857143
# 5    9990000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 6   18990000.0  3.142857      12.000000      7.000000  458.000000   5.142857
# 7   22400000.0  2.800000      12.000000      7.000000  471.000000   6.000000
# 8   24300000.0  3.600000      12.000000      7.000000  482.285714   6.000000
# 9   11990000.0  4.034286       8.000000      7.000000  456.000000   3.000000
# 10   9990000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 11   3490000.0  5.100000       8.000000      2.000000  347.000000   2.000000
# 12  18490000.0  3.142857      12.000000      7.000000  458.000000   5.142857
# 13   3245000.0  6.300000       2.000000      2.000000  504.000000   2.000000
# 14   7990000.0  7.040000       8.000000      5.000000  467.000000   4.000000
# 15  23750000.0  2.800000      12.000000      7.000000  417.000000   6.000000
# 16   5790000.0  4.200000       8.000000      5.000000  380.000000  32.000000
# 17  24990000.0  3.600000      12.000000      7.000000  482.285714   6.000000
# 18  11490000.0  4.034286       8.000000      1.857143  495.000000   3.142857
# 19  11990000.0  4.034286       8.000000      1.000000  495.000000   3.142857
# 20  12990000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 21   1349000.0  4.350000       3.714286      1.428571   28.000000   1.428571
# 22  10990000.0  4.034286       8.000000      1.000000  495.000000   3.142857
# 23  28990000.0  3.600000      12.000000      7.000000  643.000000   6.000000
# 24  10490000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 25    979000.0  2.800000       2.000000      0.000000  236.000000   1.000000
# 26   2290000.0  5.000000       5.000000      2.000000  298.285714   2.000000
# 27   6990000.0  4.200000       8.000000      5.000000  380.000000   3.000000
# 28   1490000.0  3.700000       5.000000      2.000000  332.000000   1.000000
# 29   2550000.0  4.350000       3.714286      1.428571  298.285714   1.571429
# 30   2990000.0  4.350000       3.714286      1.428571  298.285714   2.000000
# 31   1400000.0  2.800000       2.000000      0.000000  278.000000   1.000000
# 32   2249000.0  4.750000       2.000000      2.000000  363.000000   1.000000
#
#     rank_point
# 0   146.800607
# 1    30.323938
# 2    47.454220
# 3    46.839933
# 4    34.948919
# 5   306.364087
# 6    12.621598
# 7    13.389456
# 8     7.180719
# 9   198.665099
# 10  117.471330
# 11  218.547077
# 12    4.680595
# 13    8.575874
# 14   19.688527
# 15    7.170901
# 16    6.725116
# 17    5.748044
# 18   13.377699
# 19    2.045043
# 20   14.703157
# 21    9.954593
# 22    3.437712
# 23    0.783160
# 24   10.254126
# 25    0.500000
# 26    7.205533
# 27   10.811081
# 28    4.456724
# 29    1.588047
# 30    1.203179
# 31   17.997359
# 32  113.994853

# %%
from sklearn.preprocessing import StandardScaler

Standard_scaler = StandardScaler()
Xtrans = Standard_scaler.fit_transform(Xtrans)

# %%
rank_data_scaled = pd.DataFrame(Xtrans,index=rank_data.index, columns=rank_data.columns)

# %%
from skcriteria import Data, MIN, MAX
ranking = Data(
    rank_data_scaled,
    [MIN, MAX, MAX, MAX, MIN, MAX, MAX],
    cnames = rank_data.columns,
    weights = [0.1,1,0.1,0.1,1,1,100]
)

# %%
from skcriteria.madm import simple
dm = simple.WeightedSum(mnorm = "sum",wnorm = "sum")
dec = dm.decide(ranking)

# %%
rank_data['rank'] = dec.rank_[::-1]
rank_data.sort_values(by=['rank'])
# Out:
#          price   pin(ah)  front_cam(MP)  rear_cam(MP)      weight    RAM(GB)  \
# 7   22400000.0  2.800000      12.000000      7.000000  471.000000   6.000000
# 9   11990000.0  4.034286       8.000000      7.000000  456.000000   3.000000
# 2   20490000.0  2.800000      12.000000      7.000000  471.000000   6.000000
# 3    3019000.0  4.350000       3.714286      1.428571  298.285714   1.571429
# 13   3245000.0  6.300000       2.000000      2.000000  504.000000   2.000000
# 10   9990000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 4   15490000.0  3.634286      12.000000      7.000000  458.000000   3.857143
# 20  12990000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 16   5790000.0  4.200000       8.000000      5.000000  380.000000  32.000000
# 15  23750000.0  2.800000      12.000000      7.000000  417.000000   6.000000
# 24  10490000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 6   18990000.0  3.142857      12.000000      7.000000  458.000000   5.142857
# 17  24990000.0  3.600000      12.000000      7.000000  482.285714   6.000000
# 19  11990000.0  4.034286       8.000000      1.000000  495.000000   3.142857
# 11   3490000.0  5.100000       8.000000      2.000000  347.000000   2.000000
# 8   24300000.0  3.600000      12.000000      7.000000  482.285714   6.000000
# 5    9990000.0  3.200000       8.000000      1.000000  483.000000   3.000000
# 26   2290000.0  5.000000       5.000000      2.000000  298.285714   2.000000
# 14   7990000.0  7.040000       8.000000      5.000000  467.000000   4.000000
# 25    979000.0  2.800000       2.000000      0.000000  236.000000   1.000000
# 12  18490000.0  3.142857      12.000000      7.000000  458.000000   5.142857
# 1   10950000.0  4.034286       8.000000      1.000000  495.000000   3.142857
# 18  11490000.0  4.034286       8.000000      1.857143  495.000000   3.142857
# 31   1400000.0  2.800000       2.000000      0.000000  278.000000   1.000000
# 28   1490000.0  3.700000       5.000000      2.000000  332.000000   1.000000
# 29   2550000.0  4.350000       3.714286      1.428571  298.285714   1.571429
# 30   2990000.0  4.350000       3.714286      1.428571  298.285714   2.000000
# 0    8490000.0  4.034286       8.000000      2.142857  495.000000   7.285714
# 22  10990000.0  4.034286       8.000000      1.000000  495.000000   3.142857
# 32   2249000.0  4.750000       2.000000      2.000000  363.000000   1.000000
# 23  28990000.0  3.600000      12.000000      7.000000  643.000000   6.000000
# 21   1349000.0  4.350000       3.714286      1.428571   28.000000   1.428571
# 27   6990000.0  4.200000       8.000000      5.000000  380.000000   3.000000
#
#     rank_point  rank
# 7    13.389456     1
# 9   198.665099     2
# 2    47.454220     3
# 3    46.839933     4
# 13    8.575874     5
# 10  117.471330     6
# 4    34.948919     7
# 20   14.703157     8
# 16    6.725116     9
# 15    7.170901    10
# 24   10.254126    11
# 6    12.621598    12
# 17    5.748044    13
# 19    2.045043    14
# 11  218.547077    15
# 8     7.180719    16
# 5   306.364087    17
# 26    7.205533    18
# 14   19.688527    19
# 25    0.500000    20
# 12    4.680595    21
# 1    30.323938    22
# 18   13.377699    23
# 31   17.997359    24
# 28    4.456724    25
# 29    1.588047    26
# 30    1.203179    27
# 0   146.800607    28
# 22    3.437712    29
# 32  113.994853    30
# 23    0.783160    31
# 21    9.954593    32
# 27   10.811081    33

# %%
cols_to_keep = ['index', 'name', 'brand', 'number_of_comment', 'Negative', 'Positive']
group_data = group_data.drop(group_data.columns.difference(cols_to_keep), axis=1)

# %%
pd.concat([group_data, rank_data], axis=1, join="inner").to_csv('tablet_done.csv')
