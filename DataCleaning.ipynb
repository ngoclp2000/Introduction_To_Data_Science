# %%
# Importing library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data

# %%
# For Phone data

# %%
# normal phone
normal_phone = pd.read_csv('./data/phone_and_table/normal_phone.csv')
#normal_phone.info()
normal_phone
# Out:
#       index                                               name   price  \
# 0         0  Điện Thoại Nokia 105 Dual Sim (2019) - Hàng Ch...  350000
# 1         0  Điện Thoại Nokia 105 Dual Sim (2019) - Hàng Ch...  350000
# 2         0  Điện Thoại Nokia 105 Dual Sim (2019) - Hàng Ch...  350000
# 3         0  Điện Thoại Nokia 105 Dual Sim (2019) - Hàng Ch...  350000
# 4         0  Điện Thoại Nokia 105 Dual Sim (2019) - Hàng Ch...  350000
# ...     ...                                                ...     ...
# 2655    102  Điện Thoại Di Động GSM Zono N105 - Hàng Nhập K...  349000
# 2656    102  Điện Thoại Di Động GSM Zono N105 - Hàng Nhập K...  349000
# 2657    102  Điện Thoại Di Động GSM Zono N105 - Hàng Nhập K...  349000
# 2658    102  Điện Thoại Di Động GSM Zono N105 - Hàng Nhập K...  349000
# 2659    102  Điện Thoại Di Động GSM Zono N105 - Hàng Nhập K...  349000
#
#       number_of_comment       pin  brand front_cam rear_cam weight  RAM  \
# ...

# %%
# smart phone
smart_phone = pd.read_csv('./data/phone_and_table/smart_phone.csv')
smart_phone
# Out:
#        index                                               name     price  \
# 0          0  Điện thoại Vivo Y11 (3GB/32GB) - Hàng chính hãng    2550000
# 1          0  Điện thoại Vivo Y11 (3GB/32GB) - Hàng chính hãng    2550000
# 2          0  Điện thoại Vivo Y11 (3GB/32GB) - Hàng chính hãng    2550000
# 3          0  Điện thoại Vivo Y11 (3GB/32GB) - Hàng chính hãng    2550000
# 4          0  Điện thoại Vivo Y11 (3GB/32GB) - Hàng chính hãng    2550000
# ...      ...                                                ...       ...
# 10842    129  Điện Thoại Infinix HOT S (X521) - Hàng Chính H...   2350000
# 10843    129  Điện Thoại Infinix HOT S (X521) - Hàng Chính H...   2350000
# 10844    129  Điện Thoại Infinix HOT S (X521) - Hàng Chính H...   2350000
# 10845    130  Điện thoại Black shark 3 (8GB/128GB) - Hàng QU...  14490000
# 10846    136  Điện Thoại Oukitel K12 (RAM 6Gb/ROM 64GB PIN 1...   6990000
#
#        number_of_comment       pin        brand  \
# ...

# %%
# reading table 
reading_table = pd.read_csv('./data/phone_and_table/reading_table.csv')
reading_table
# Out:
#       index                                               name     price  \
# 0         0  Máy Đọc Sách Kindle Paperwhite Gen 10 - Hàng N...   2890000
# 1         0  Máy Đọc Sách Kindle Paperwhite Gen 10 - Hàng N...   2890000
# 2         0  Máy Đọc Sách Kindle Paperwhite Gen 10 - Hàng N...   2890000
# 3         0  Máy Đọc Sách Kindle Paperwhite Gen 10 - Hàng N...   2890000
# 4         0  Máy Đọc Sách Kindle Paperwhite Gen 10 - Hàng N...   2890000
# ...     ...                                                ...       ...
# 1388     24  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...   2249000
# 1389     24  Máy Tính Bảng Kindle Fire HD8 (8th) 16GB (2019...   2249000
# 1390     29  Máy Đọc Sách Boox Note Plus (Note+) - Hàng Nhậ...  11490000
# 1391     31   Máy đọc sách Onyx Boox Note 2 - HÀNG CHÍNH HÃNG   13590000
# 1392     32     Máy Đọc Sách Likebook Muses - Hàng chính hãng    6590000
#
#       number_of_comment       pin      brand front_cam rear_cam  weight  \
# ...

# %%
# table 
table = pd.read_csv('./data/phone_and_table/table.csv')
table.price
# Out:
# 0       8490000
# 1       8490000
# 2       8490000
# 3       8490000
# 4       8490000
#          ...
# 1978    2249000
# 1979    2249000
# 1980    2249000
# 1981    2249000
# 1982    2249000
# Name: price, Length: 1983, dtype: int64

# %%
## Camera
camera = pd.read_csv('./data/camera/camera.csv')
camera
# Out:
#       index                                               name     price  \
# 0         0  Máy Ảnh Lấy Liền Fujifilm Instax Mini 11-Hàng ...   1890000
# 1         0  Máy Ảnh Lấy Liền Fujifilm Instax Mini 11-Hàng ...   1890000
# 2         0  Máy Ảnh Lấy Liền Fujifilm Instax Mini 11-Hàng ...   1890000
# 3         0  Máy Ảnh Lấy Liền Fujifilm Instax Mini 11-Hàng ...   1890000
# 4         0  Máy Ảnh Lấy Liền Fujifilm Instax Mini 11-Hàng ...   1890000
# ...     ...                                                ...       ...
# 1584    196  Máy ảnh Olympus OM-D E-M10 Mark III + Kit 14-4...  14500000
# 1585    197  Máy Ảnh Fujifilm X-Pro 2 + 23mm F2 Black - Hàn...  50480000
# 1586    198        Máy Ảnh Sony DSC-RX100M5A - Hàng Chính Hãng  20990000
# 1587    199    Máy ảnh Olympus E-M1X (Body) ( Hàng Chính hãng)  72000000
# 1588    200  Máy ảnh kỹ thuật số Paper Shoot chính hãng  13...   4350000
#
#       number_of_comment        brand                                 size  \
# ...

# %%
## Electric Device
#washing machine
washing_machine = pd.read_csv('./data/electric_device/washing_machine.csv')
washing_machine.name
# Out:
# 0         Máy giặt Toshiba Inverter 8.5 Kg TW-BH95S2V WK
# 1         Máy giặt Toshiba Inverter 8.5 Kg TW-BH95S2V WK
# 2         Máy giặt Toshiba Inverter 8.5 Kg TW-BH95S2V WK
# 3         Máy giặt Toshiba Inverter 8.5 Kg TW-BH95S2V WK
# 4         Máy giặt Toshiba Inverter 8.5 Kg TW-BH95S2V WK
#                               ...
# 2495    Máy giặt Aqua 11kg AQW-FW110FT-N - HÀNG CHÍNH ...
# 2496         Máy giặt Aqua Inverter 10.5 kg AQD-D1050E N
# 2497    Máy Giặt Cửa Trước Samsung Inverter WW90J54E0B...
# 2498    Máy giặt Electrolux Inverter 9 kg EWF9024BDWA ...
# 2499    Máy Giặt Cửa Trên Panasonic NA-F100V5LRV (10kg...
# Name: name, Length: 2500, dtype: object

# %%
## Electric Device
#washing machine
tivi = pd.read_csv('./data/electric_device/tivi.csv')
tivi.info()
tivi.price.min()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5701 entries, 0 to 5700
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              5701 non-null   int64
#  1   name               5701 non-null   object
#  2   price              5700 non-null   float64
#  3   number_of_comment  5700 non-null   float64
#  4   brand              5700 non-null   object
#  5   size               5259 non-null   object
#  6   display            5133 non-null   object
#  7   type               5277 non-null   object
#  8   weight             4002 non-null   object
#  9   comment            5406 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 445.5+ KB
# 950000.0

# %%
## Electric Device
#fridge
fridge = pd.read_csv('./data/electric_device/fridge.csv')
fridge
# Out:
#       index                                               name     price  \
# 0         0          Tủ Lạnh Sharp Inverter 556L SJ-FX631V-SL   14499000
# 1         0          Tủ Lạnh Sharp Inverter 556L SJ-FX631V-SL   14499000
# 2         0          Tủ Lạnh Sharp Inverter 556L SJ-FX631V-SL   14499000
# 3         0          Tủ Lạnh Sharp Inverter 556L SJ-FX631V-SL   14499000
# 4         0          Tủ Lạnh Sharp Inverter 556L SJ-FX631V-SL   14499000
# ...     ...                                                ...       ...
# 2687    548  Tủ Lạnh Inverter Mitsubishi Electric MR-CGX41E...  14480000
# 2688    552  Tủ Lạnh Inverter Panasonic NR-BL26AVPVN (234L)...   5979000
# 2689    554  Tủ Lạnh Inverter Electrolux EHE6879A-BCVN (615...  37090000
# 2690    558  Tủ lạnh Electrolux Inverter 350 Lít ETB3700J-A...   9749000
# 2691    574  Tủ Lạnh Inverter LG GN-D315S (315L) – Hàng Chí...   8379000
#
#       number_of_comment                brand  \
# ...

# %%
#laptop
laptop = pd.read_csv('./data/laptop/Laptop.csv')
laptop.info()
laptop.display.dropna().max()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              908 non-null    int64
#  1   name               908 non-null    object
#  2   price              908 non-null    int64
#  3   number_of_comment  908 non-null    int64
#  4   brand              908 non-null    object
#  5   CPU                763 non-null    object
#  6   hardware_size      806 non-null    object
#  7   RAM                813 non-null    object
#  8   resolution         709 non-null    object
#  9   display            779 non-null    float64
#  10  comment            763 non-null    object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 78.2+ KB
# 21.5
